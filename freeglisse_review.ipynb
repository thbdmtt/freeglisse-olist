# %% [markdown]
# # Freeglisse Products Reviews Scrapping

# %% [markdown]
# ## Setup and Configuration

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# ## Data collection process

# %% [markdown]
# ### Function to get all URLs products

# %%
def get_all_product_urls(base_url):
    all_product_urls = []
    current_page = 1
    while True:
        # Build the current page URL by adding the pagination parameter
        url = f"{base_url}?page={current_page}"
        response = requests.get(url)
        # Break the loop if the page request was unsuccessful
        if response.status_code != 200:
            break 

        soup = BeautifulSoup(response.content, 'html.parser')
        products = soup.find_all('div', class_='product')

        # Find the URL for each product and add it to the list
        page_product_urls = [p.find('a')['href'] for p in products if p.find('a')]
        if not page_product_urls:
            break  # Stop if no product URLs are found on the page

        all_product_urls.extend(page_product_urls)

        # Check if there is a next page
        next_button = soup.find('a', rel='next')
        if not next_button or 'disabled' in next_button.get('class', []):
            break  # Stop if there is no 'next' button or if it's disabled
        
        current_page += 1  # Increment the page number
        
    return all_product_urls


# URL of the first page of products
base_url = 'https://freeglisse.com/fr/12-ski-occasion'
product_urls = get_all_product_urls(base_url)

# %% [markdown]
# ### Function to extract all datas we need of a single page

# %%
def scrape_product_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the canonical link; use conditional to check for the tag's existence
    canonical_link = soup.find('link', rel='canonical')['href'] if soup.find('link', rel='canonical') else None
    
    # Extract the client's name
    client_name_tag = soup.find('p', class_='netreviews_customer_name')
    # Remove surrounding quotes if present and check for tag's existence
    client_name = client_name_tag.get_text(strip=True).strip('"') if client_name_tag else None
    
    # Extract the comment's publication date
    # Use find_next_sibling to find the date related to the client name tag
    comment_date_tag = client_name_tag.find_next_sibling('span') if client_name_tag else None
    # Split the text to get the date after 'le' and strip any whitespace
    comment_date = comment_date_tag.get_text(strip=True).split('le')[-1].strip() if comment_date_tag else None


    # Extract the order date
    order_date = None
    order_date_tag = soup.find('span', class_='order_date')
    if order_date_tag:
        # Split the text to get the date after 'du' and strip any whitespace
        order_date = order_date_tag.get_text(strip=True).split('du')[-1].strip()


    # Extract the rating
    rating = None
    rating_tag = soup.find('div', class_='netreviews_reviews_rate')
    if rating_tag:
        # Extract the rating text directly
        rating = rating_tag.get_text(strip=True)

    # Extract the comment
    comment = None
    comment_tag = soup.find('p', class_='netreviews_customer_review')
    if comment_tag:
        # Extract the comment text directly
        comment = comment_tag.get_text(strip=True)

    # Construct and return a dictionary of the product's information
    return {
        'link': canonical_link,
        'client_name': client_name,
        'order_date': order_date,
        'comment_date': comment_date,
        'rating': rating,
        'comment': comment
    }

# %% [markdown]
# ### Extract datas of all pages

# %%
# URL of the first page of the products
base_url = 'https://freeglisse.com/fr/12-ski-occasion'
product_urls = get_all_product_urls(base_url)

# List to store details of all products
all_product_details = []

# Browse each product URL and retrieve details
for url in product_urls:
    details = scrape_product_page(url)
    all_product_details.append(details)

all_product_details
# Out:
# [{'link': 'https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html',
#   'client_name': 'FERNAND L.publié le 17/04/2024suite à une commande du 09/04/2024',
#   'order_date': '09/04/2024',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': "Hormis le problème de fixations après avoir pris le soins de les lustré préparé les cares et fartage la notation qualité A n'ai pas mis en  défaut."},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18915-ski-occasion-rossignol-sender-94-ti-2023-fixations.html',
#   'client_name': 'Peio A.publié le 11/11/2023suite à une commande du 01/11/2023',
#   'order_date': '01/11/2023',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'good cuality'},
#  {'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18974-ski-de-fond-occasion-rossignol-lts-junior-fixation-sns-profil.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/15468-ski-de-fond-occasion-toutes-marques-fixation-sns-profil.html',
#   'client_name': 'Etienne H.publié le 30/01/2023suite à une commande du 16/01/2023',
#   'order_date': '16/01/2023',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': "Je n'ai pas encore pu les tester car pas de chaussure dispo a la vente pour la pointure. Mais les écailles semblent encore en bon etat"},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-femme-loisir/18890-ski-occasion-rossignol-nova-6-fixations.html',
#   'client_name': 'Marie D.publié le 25/02/2024suite à une commande du 04/02/2024',
#   'order_date': '04/02/2024',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Etat du produit conforme à mes attentes!'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/18084-ski-occasion-junior-toutes-marques-a-29-fixations.html',
#   'client_name': 'Delphine D.publié le 09/04/2024suite à une commande du 29/03/2024',
#   'order_date': '29/03/2024',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'skis en bon état, peu utilisés, assez rapides'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/1795-ski-occasion-junior-toutes-marques-a-19-fixations.html',
#   'client_name': 'MELINDA B.publié le 22/01/2023suite à une commande du 11/01/2023',
#   'order_date': '11/01/2023',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'impeccable'},
#  {'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/15483-ski-de-fond-occasion-toutes-marques-fixation-vieux-sns.html',
#   'client_name': 'Client anonymepublié le 22/01/2022suite à une commande du 09/01/2022',
#   'order_date': '09/01/2022',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Etat correct'},
#  {'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18999-ski-de-fond-occasion-toutes-marques-fixation-sns-profil.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/14329-ski-junior-rossignol-star-wars-occasion-fixations.html',
#   'client_name': 'Peter K.publié le 21/02/2024suite à une commande du 09/02/2024',
#   'order_date': '09/02/2024',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Sehr guter Zustand'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-femme-pas-cher/16352-ski-occasion-femme-toutes-marques-tous-modeles-a-29-fixations.html',
#   'client_name': 'GUSTAVO M.publié le 07/04/2024suite à une commande du 14/03/2024',
#   'order_date': '14/03/2024',
#   'comment_date': None,
#   'rating': '3/5',
#   'comment': 'no lo puedo valorar'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13078-ski-occasion-salomon-tous-modeles-a-29-fixations.html',
#   'client_name': 'Eloy N.publié le 26/12/2023suite à une commande du 17/12/2023',
#   'order_date': '17/12/2023',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Surpris par le bon état des skis'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18284-ski-occasion-dynastar-speed-zone-4x4-78-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/14533-ski-occasion-junior-dynastar-team-speed-fixations.html',
#   'client_name': 'Jonathan D.publié le 09/01/2024suite à une commande du 30/12/2023',
#   'order_date': '30/12/2023',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Conforme à ce qui est annoncé'},
#  {'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18972-ski-de-fond-occasion-rossignol-progress-fixaxion-sns-profil.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-nnn/18914-ski-de-fond-occasion-fischer-cruiser-crown-fixation-nnn.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13097-ski-occasion-atomic-tous-modele-a-29-fixations.html',
#   'client_name': 'Emilie E.publié le 03/02/2024suite à une commande du 19/01/2024',
#   'order_date': '19/01/2024',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Très bon état nous allons les tester le 3 février !!!'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-loisir/18536-ski-occasion-dynastar-legend-x-75-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/17203-ski-occasion-k2-thrilluvit-85-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18381-ski-occasion-dynastar-speed-zone-4x4-82-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/18929-ski-occasion-atomic-cloud-q9-fixations.html',
#   'client_name': 'Bertrand J.publié le 20/12/2023suite à une commande du 06/12/2023',
#   'order_date': '06/12/2023',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Idem'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/16346-ski-fille-occasion-junior-toutes-marques-a-29-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13090-ski-occasion-rossignol-tous-modele-a-29-fixations.html',
#   'client_name': 'DONNA M.publié le 08/02/2023suite à une commande du 02/02/2023',
#   'order_date': '02/02/2023',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Parfait!'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13081-ski-occasion-adulte-k2-tous-modeles-a-29-fixations.html',
#   'client_name': 'Client anonymepublié le 20/03/2022suite à une commande du 14/03/2022',
#   'order_date': '14/03/2022',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Me semblent bien mais pas essayé. Livraison rapide'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/16346-ski-fille-occasion-junior-toutes-marques-a-29-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/18966-ski-occasion-rossignol-strato-edition-2023-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/16751-ski-occasion-nordica-navigator-85-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13096-ski-occasion-dynastar-tous-modele-a-29-fixations.html',
#   'client_name': 'JF L.publié le 06/03/2023suite à une commande du 28/02/2023',
#   'order_date': '28/02/2023',
#   'comment_date': None,
#   'rating': '3/5',
#   'comment': 'Matériel un peu vieillot en Dynastar, autant voir sur les autres marques'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13083-ski-occasion-volkl-tous-modele-a-29-fixations.html',
#   'client_name': 'Sébastien R.publié le 27/02/2024suite à une commande du 21/02/2024',
#   'order_date': '21/02/2024',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Nickel'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-femme-performance/15968-ski-occasion-fischer-brilliant-my-turn-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13085-ski-occasion-elan-tous-modele-a-29-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freeride/18418-ski-occasion-volkl-secret-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/18333-ski-occasion-junior-dynastar-slider-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/12512-ski-occasion-junior-head-supershape-fixations.html',
#   'client_name': 'Client anonymepublié le 04/12/2023suite à une commande du 20/11/2023',
#   'order_date': '20/11/2023',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': "Semelles et carres en bon état c'est le plus important..."},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/14483-ski-occasion-junior-tecnopro-team-pulse-fixations.html',
#   'client_name': 'Sophie D.publié le 26/12/2023suite à une commande du 15/12/2023',
#   'order_date': '15/12/2023',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Ski comme prévu sur le site'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freeride/18415-ski-occasion-kastle-fx-96-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freestyle/18382-ski-occasion-armada-arv-84-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/17099-ski-occasion-dynastar-intense-4x4-78-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/18548-ski-occasion-junior-salomon-s-race-jr-fixations.html',
#   'client_name': 'Elodie M.publié le 20/12/2023suite à une commande du 10/12/2023',
#   'order_date': '10/12/2023',
#   'comment_date': None,
#   'rating': '3/5',
#   'comment': 'Dommage que les défauts ne soient pas mieux décris ou en photo'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-loisir/13390-ski-occasion-volkl-rtm-74-fixations.html',
#   'client_name': 'Sebastien G.publié le 30/01/2024suite à une commande du 13/01/2024',
#   'order_date': '13/01/2024',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Très bien'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-freeride-freestyle/11479-ski-occasion-junior-nordica-ace-of-spades-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/14269-ski-occasion-junior-tecnopro-team-pulse-fixations.html',
#   'client_name': 'Thomas L.publié le 30/04/2023suite à une commande du 23/04/2023',
#   'order_date': '23/04/2023',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Super'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/18638-ski-occasion-head-kore-93-w-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/17721-ski-occasion-fischer-xtr-race-fixations.html',
#   'client_name': 'Guillaume S.publié le 25/02/2024suite à une commande du 12/02/2024',
#   'order_date': '12/02/2024',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Top👍'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-femme-performance/17653-ski-occasion-rossignol-nova-8-ca-2022-fixations.html',
#   'client_name': 'Didier H.publié le 16/01/2023suite à une commande du 30/12/2022',
#   'order_date': '30/12/2022',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Pour moi le A devrait se différencier en plus avec un "+" et un" -" exemple : A+ , dans ce cas j\'aurais noté cette paire de ski en A- voir B+ . Je pense que la on serait parfait'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/18668-ski-occasion-nordica-dobermann-spitfire-crx-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-loisir/18711-ski-occasion-salomon-s-force-x6-fixations.html',
#   'client_name': 'Raoul C.publié le 18/02/2024suite à une commande du 03/02/2024',
#   'order_date': '03/02/2024',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Matériel conforme à la description. Carres affutés, semelles en parfait état, fartage OK... Impatient de les tester sur les pistes'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freestyle/14701-ski-occasion-atomic-punx-5-fixations.html',
#   'client_name': 'Sasu U.publié le 18/01/2024suite à une commande du 03/01/2024',
#   'order_date': '03/01/2024',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Skis are like described'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13086-ski-occasion-scott-tous-modele-a-29-fixations.html',
#   'client_name': 'Etienne H.publié le 30/01/2023suite à une commande du 16/01/2023',
#   'order_date': '16/01/2023',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Autre marque reçue (marqué inconnue) mais fonctionnels malgré la classe C. J\'ai reçu un modèle a spatule large, a priori d\'une gamme de loueur un peu moins "standard"'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-femme-performance/17653-ski-occasion-rossignol-nova-8-ca-2022-fixations.html',
#   'client_name': 'Didier H.publié le 16/01/2023suite à une commande du 30/12/2022',
#   'order_date': '30/12/2022',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Pour moi le A devrait se différencier en plus avec un "+" et un" -" exemple : A+ , dans ce cas j\'aurais noté cette paire de ski en A- voir B+ . Je pense que la on serait parfait'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-femme-performance/18922-ski-occasion-rossignol-nova-8-ca-2023-fixations.html',
#   'client_name': 'Valérie R.publié le 10/02/2024suite à une commande du 04/02/2024',
#   'order_date': '04/02/2024',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': "Pris an qualité A, présente bien les traces d'usage d'une saison, beaucoup de griffes et des quelques impacts sur le dessus du ski mais rien de bien méchant. Hate de les essayer"},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freeride/14644-ski-occasion-dynastar-cham-87-fixations.html',
#   'client_name': 'Client anonymepublié le 07/02/2022suite à une commande du 26/01/2022',
#   'order_date': '26/01/2022',
#   'comment_date': None,
#   'rating': '3/5',
#   'comment': "-Manque d'informations plus précise sur l'état général du matériel sur le site, juste un récapitulatif généralisé sur la notation A,B et C.\r\n-A réception j'aurai plutôt mis la lettre B (A sur le site), semelle et care OK, fixation et dessus de ski avec bon nombres de rayures. Maintenant c'est qu'à 'usage que je verrais si c'est pleinement OK."},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/13805-ski-occasion-rossignol-radical-9-gs-worldcup-ti-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/12945-ski-occasion-head-shape-tx-fixations.html',
#   'client_name': 'Maurizio D.publié le 16/01/2023suite à une commande du 03/01/2023',
#   'order_date': '03/01/2023',
#   'comment_date': None,
#   'rating': '3/5',
#   'comment': 'Troppo usurati anche per un grado C'},
#  {'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-skating-norme-sns/18996-ski-de-fond-occasion-junior-fischer-rcr-skatecut-fixation-sns-pilot.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/17058-ski-occasion-nordica-transfire-rtx-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-freeride-freestyle/17817-ski-occasion-junior-salomon-shogun-jr-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/15523-ski-occasion-junior-fischer-rc4-race-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/10713-ski-occasion-rossignol-9-gs-worldcup-ti-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18598-ski-occasion-elan-amphibio-84-ti-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/12420-ski-occasion-junior-dynastar-team-cham-fixations.html',
#   'client_name': 'Sylvain T.publié le 21/02/2024suite à une commande du 08/02/2024',
#   'order_date': '08/02/2024',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Conforme à la description'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-loisir/18550-ski-occasion-atomic-performer-xt-fixations.html',
#   'client_name': 'Philippe M.publié le 18/02/2024suite à une commande du 06/02/2024',
#   'order_date': '06/02/2024',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Certains  défauts  auraient  put être mentionnés. Livraison rapide .'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/14076-ski-occasion-nordica-dobermann-spitfire-pro-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13088-ski-occasion-movement-tous-modele-a-29-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/14637-ski-occasion-atomic-vantage-86c-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/12462-ski-occasion-junior-tecnopro-team-pulse-fixations.html',
#   'client_name': 'Annie B.publié le 01/01/2024suite à une commande du 21/12/2023',
#   'order_date': '21/12/2023',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'excellent'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/17053-ski-occasion-rossignol-react-6-compact-fixations.html',
#   'client_name': 'Alfredo S.publié le 18/01/2024suite à une commande du 05/01/2024',
#   'order_date': '05/01/2024',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Perfect'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/17758-ski-occasion-fischer-rc4-the-curv-fixations.html',
#   'client_name': 'Nicolas C.publié le 09/02/2024suite à une commande du 01/02/2024',
#   'order_date': '01/02/2024',
#   'comment_date': None,
#   'rating': '3/5',
#   'comment': "si vous demandez pointure et poid je suppose que c'est pour avoir la possibilité de prérégler les fixations et ce n'est pas le cas"},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-loisir/12615-ski-occasion-rossignol-experience-75-carbon-fixations.html',
#   'client_name': 'Client anonymepublié le 09/01/2024suite à une commande du 30/12/2023',
#   'order_date': '30/12/2023',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Il prodotto in ottimo stato, la qualità A rispecchia assolutamente le aspettative.'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/14171-ski-occasion-dynastar-legend-x-80-fixations.html',
#   'client_name': 'Vincent B.publié le 31/01/2023suite à une commande du 24/01/2023',
#   'order_date': '24/01/2023',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Conforme à mes attentes'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freestyle/16555-ski-occasion-elan-sling-shot-fixations.html',
#   'client_name': 'Olivier V.publié le 16/01/2024suite à une commande du 02/01/2024',
#   'order_date': '02/01/2024',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'RAS \r\n\r\nQuelques accros sur le dessus et semelles nickelles'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freestyle/17827-ski-occasion-volkl-alley-fixations.html',
#   'client_name': 'Christophe Jean R.publié le 08/02/2023suite à une commande du 31/01/2023',
#   'order_date': '31/01/2023',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Produit conforme à la photo et la description ( ce n’est pas du neuf).\r\nLes renseignements sur l’utilisateur (taille de pied et poids)  bien pris en compte.'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-loisir/18700-ski-occasion-dynastar-legend-75-r-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/15523-ski-occasion-junior-fischer-rc4-race-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-femme-loisir/18545-ski-occasion-blizzard-elevate-77-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/14637-ski-occasion-atomic-vantage-86c-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freestyle/17827-ski-occasion-volkl-alley-fixations.html',
#   'client_name': 'Christophe Jean R.publié le 08/02/2023suite à une commande du 31/01/2023',
#   'order_date': '31/01/2023',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Produit conforme à la photo et la description ( ce n’est pas du neuf).\r\nLes renseignements sur l’utilisateur (taille de pied et poids)  bien pris en compte.'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18598-ski-occasion-elan-amphibio-84-ti-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/10713-ski-occasion-rossignol-9-gs-worldcup-ti-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/14184-ski-occasion-junior-elan-race-rc-waveflex-fixations.html',
#   'client_name': 'Joris K.publié le 17/12/2022suite à une commande du 04/12/2022',
#   'order_date': '04/12/2022',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Pas nouveau mais bonne condition.'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/18649-ski-occasion-fischer-my-pro-mt-80-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/10686-ski-occasion-scott-luna-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/18363-ski-occasion-lacroix-pure-fixations.html',
#   'client_name': 'Arnaud J.publié le 07/12/2023suite à une commande du 19/11/2023',
#   'order_date': '19/11/2023',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'État en rapport avec description \r\nPas encore essayés'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/18372-ski-occasion-volkl-deacon-74-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/17209-ski-occasion-head-supershape-imagnum-fixations.html',
#   'client_name': 'Fabrizii M.publié le 21/02/2024suite à une commande du 10/02/2024',
#   'order_date': '10/02/2024',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Top!'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/17170-ski-occasion-atomic-redster-g9-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-loisir/14627-ski-occasion-elan-element-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-loisir/15137-ski-occasion-volkl-rtm-74-fixation.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/16426-ski-occasion-head-worldcup-rebels-irace-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/15991-ski-occasion-head-ishape-rush-fixations.html',
#   'client_name': 'Luca C.publié le 09/01/2024suite à une commande du 27/12/2023',
#   'order_date': '27/12/2023',
#   'comment_date': None,
#   'rating': '3/5',
#   'comment': 'Considerando che si tratta di un prodotto usato anzi usatissimo mi aspettavo dei difetti estetici e qualche segno sulle solette, ma che addirittura nel bordo della copertura superiore lo strato di alluminio sia abbozzato e sollevato non me lo aspettavo.\r\nDirei di fare attenzione ai tecnici responsabili della selezione perché per non è da categoria B'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/11927-ski-occasion-salomon-x-wing-8-fixations.html',
#   'client_name': 'Client anonymepublié le 16/12/2020suite à une commande du 09/12/2020',
#   'order_date': '09/12/2020',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Genial!'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/16851-ski-occasion-junior-tecnopro-flyte-jr-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-test-all-mountain/15020-ski-test-kastle-fx-95-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/13052-ski-occasion-lacroix-lx-gravity-fixations.html',
#   'client_name': 'Laurent D.publié le 05/12/2022suite à une commande du 25/11/2022',
#   'order_date': '25/11/2022',
#   'comment_date': None,
#   'rating': '3/5',
#   'comment': 'Pour une qualité A, je m’attendais à une meilleure présentation. A voir à l’usage.'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freeride/17648-ski-occasion-rossignol-blackops-sender-2022-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freeride/17518-ski-occasion-salomon-rocker-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-loisir/15181-ski-occasion-head-rev-78-fixations.html',
#   'client_name': 'Noel C.publié le 27/12/2022suite à une commande du 13/12/2022',
#   'order_date': '13/12/2022',
#   'comment_date': None,
#   'rating': '3/5',
#   'comment': 'les coups presents sont un peu plus prononcés que definis dans la description de la qualité'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-loisir/17164-ski-occasion-fischer-my-xtr-mt-77-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/11927-ski-occasion-salomon-x-wing-8-fixations.html',
#   'client_name': 'Client anonymepublié le 16/12/2020suite à une commande du 09/12/2020',
#   'order_date': '09/12/2020',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Genial!'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/13566-ski-occasion-kastle-mx-83-fixations.html',
#   'client_name': 'Client anonymepublié le 23/12/2021suite à une commande du 13/12/2021',
#   'order_date': '13/12/2021',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Material conforme a lo especificado. Buena relación calidad precio. Los esquis aun no los he probado, por lo que no puedo valorarlos. Se agradecería que se especificase también el modelo de fijación (el producto viene de tiendas de alquiler, y las fijaciones parecen algo distintas a las de venta en tienda'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/14173-ski-occasion-fischer-pro-mtn-80-ti-fixations.html',
#   'client_name': 'Alessandro B.publié le 26/12/2023suite à une commande du 15/12/2023',
#   'order_date': '15/12/2023',
#   'comment_date': None,
#   'rating': '3/5',
#   'comment': "je pensais qu'ils seraient moins endommagés"},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/14296-ski-occasion-head-monster-78-fixation.html',
#   'client_name': 'Client anonymepublié le 23/02/2022suite à une commande du 13/02/2022',
#   'order_date': '13/02/2022',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Bon état envoi rapide'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/14344-ski-occasion-movement-jam-er-fixation.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/14380-ski-occasion-scott-slight-83-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/16815-ski-occasion-kastle-mx-84-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18439-ski-occasion-dynastar-m-freeski-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18549-ski-occasion-dps-cassiar-foundation-f82-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18917-ski-occasion-rossignol-experience-86-basalt-2023-fixations.html',
#   'client_name': 'Alexandre B.publié le 06/03/2024suite à une commande du 27/02/2024',
#   'order_date': '27/02/2024',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Comme neuf'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/10867-ski-occasion-atomic-redster-g9-fixations.html',
#   'client_name': 'Client anonymepublié le 10/10/2022suite à une commande du 28/09/2022',
#   'order_date': '28/09/2022',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Leggermente più rovinati di quanto mi aspettassi sulla parte superiore ma nel complesso bene.'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/10938-ski-occasion-salomon-x-max-x10-fixations.html',
#   'client_name': 'Client anonymepublié le 13/12/2020suite à une commande du 05/12/2020',
#   'order_date': '05/12/2020',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Très bon état ,semelle et carres  impeccable.'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/11422-ski-occasion-dynastar-cr-74-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/11431-ski-occasion-volant-pulse-white-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/13052-ski-occasion-lacroix-lx-gravity-fixations.html',
#   'client_name': 'Laurent D.publié le 05/12/2022suite à une commande du 25/11/2022',
#   'order_date': '25/11/2022',
#   'comment_date': None,
#   'rating': '3/5',
#   'comment': 'Pour une qualité A, je m’attendais à une meilleure présentation. A voir à l’usage.'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/14061-ski-occasion-nordica-dobermann-spitfire-crx-fixations.html',
#   'client_name': 'Sebastien D.publié le 18/02/2024suite à une commande du 06/02/2024',
#   'order_date': '06/02/2024',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': "Ski vraiment pas cher, des impacts prononcés sur le dessus mais c'était prévisible pour de la qualité C. surface de glisse et carres en bon tat"},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/14608-ski-occasion-atomic-redster-s9-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/15190-ski-occasion-rossignol-strato-st-fixations.html',
#   'client_name': 'David V.publié le 03/02/2024suite à une commande du 22/01/2024',
#   'order_date': '22/01/2024',
#   'comment_date': None,
#   'rating': '3/5',
#   'comment': 'Très déçu de la qualité du produit reçu.\r\nPour une qualité «\xa0B\xa0» j’espérai mieux. La semelle et les carres sont renovés, mais les skis et fixations sont très endommagés… rénovation obligatoire et faite.'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/15991-ski-occasion-head-ishape-rush-fixations.html',
#   'client_name': 'Luca C.publié le 09/01/2024suite à une commande du 27/12/2023',
#   'order_date': '27/12/2023',
#   'comment_date': None,
#   'rating': '3/5',
#   'comment': 'Considerando che si tratta di un prodotto usato anzi usatissimo mi aspettavo dei difetti estetici e qualche segno sulle solette, ma che addirittura nel bordo della copertura superiore lo strato di alluminio sia abbozzato e sollevato non me lo aspettavo.\r\nDirei di fare attenzione ai tecnici responsabili della selezione perché per non è da categoria B'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/16426-ski-occasion-head-worldcup-rebels-irace-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/16753-ski-occasion-fischer-rc-one-77-xtr-fixation.html',
#   'client_name': 'Javier F.publié le 09/02/2024suite à une commande du 01/02/2024',
#   'order_date': '01/02/2024',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Cumplen las características indicadas en la descripción. Solo queda probarlos.'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/16860-ski-occasion-dps-foundation-uschi-87-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/17116-ski-occasion-rossignol-pursuit-600-cam-fixations.html',
#   'client_name': 'Paul N.publié le 18/02/2024suite à une commande du 06/02/2024',
#   'order_date': '06/02/2024',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Skis en bon état, ravi de ceux ci'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/17170-ski-occasion-atomic-redster-g9-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/17209-ski-occasion-head-supershape-imagnum-fixations.html',
#   'client_name': 'Fabrizii M.publié le 21/02/2024suite à une commande du 10/02/2024',
#   'order_date': '10/02/2024',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Top!'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/17263-ski-occasion-head-v-shape-lyt-v10-fixations.html',
#   'client_name': 'Sasu U.publié le 18/01/2024suite à une commande du 03/01/2024',
#   'order_date': '03/01/2024',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Skis are like described'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/17975-ski-occasion-fischer-rc4-worldcup-sc-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/18363-ski-occasion-lacroix-pure-fixations.html',
#   'client_name': 'Arnaud J.publié le 07/12/2023suite à une commande du 19/11/2023',
#   'order_date': '19/11/2023',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'État en rapport avec description \r\nPas encore essayés'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/18372-ski-occasion-volkl-deacon-74-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/18398-ski-occasion-fischer-brilliant-the-curv-fixations.html',
#   'client_name': 'Jeremie M.publié le 01/01/2024suite à une commande du 17/12/2023',
#   'order_date': '17/12/2023',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Pas de remarque particulière. \r\nProduit et état conforme à la description'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/18670-ski-occasion-head-prestige-fixations.html',
#   'client_name': 'Client anonymepublié le 20/12/2023suite à une commande du 03/12/2023',
#   'order_date': '03/12/2023',
#   'comment_date': None,
#   'rating': '1/5',
#   'comment': 'État déplorable du matériel pour une qualité A ! Par ailleurs, les couleurs et les dégâts ne correspondent pas aux photos sur le site.'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/18674-ski-occasion-fischer-rc4-my-curv-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/18685-ski-occasion-kastle-rx-12-sl-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/18881-ski-occasion-fischer-my-curv-fixations.html',
#   'client_name': 'Patrice L.publié le 03/02/2024suite à une commande du 12/01/2024',
#   'order_date': '12/01/2024',
#   'comment_date': None,
#   'rating': '3/5',
#   'comment': 'je m attendais a un meilleur état pour du catégorie A .le dessus des skis est assez abimé \r\nSinon ces Fisher My curv sont vraiment une tuerie pour carver, et les bosses .'},
#  {'link': 'https://freeglisse.com/fr/ski-test-all-mountain/15020-ski-test-kastle-fx-95-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-test-all-mountain/16856-ski-test-zag-h-96-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-test-all-mountain/17433-ski-test-zag-h-105-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freeride/15234-ski-occasion-k2-pinnacle-95-fixation.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freeride/15989-ski-occasion-dynastar-legend-94-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freeride/17445-ski-occasion-movement-go-fast-fixation.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freeride/17518-ski-occasion-salomon-rocker-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freeride/17648-ski-occasion-rossignol-blackops-sender-2022-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freeride/18356-ski-occasion-exonde-xo-97-v31-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freeride/18391-ski-occasion-rossignol-sky-7-hd-w-fixations.html',
#   'client_name': 'Jeremy P.publié le 11/12/2023suite à une commande du 24/11/2023',
#   'order_date': '24/11/2023',
#   'comment_date': None,
#   'rating': '1/5',
#   'comment': "Après réception des skis, je trouve qu'ils sont très abîmés pour une catégorie A. Très déçu par rapport au prix"},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freestyle/16913-ski-occasion-dynastar-menace-90-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freestyle/17545-ski-occasion-armada-el-rey-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-freestyle/18501-ski-occasion-volkl-revolt-95-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/12451-ski-occasion-junior-wedze-team-onebreaker-fixations.html',
#   'client_name': 'Alexandra S.publié le 03/02/2024suite à une commande du 21/01/2024',
#   'order_date': '21/01/2024',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Top!'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/12454-ski-occasion-junior-dynastar-team-cham-fixations.html',
#   'client_name': 'Client anonymepublié le 08/11/2022suite à une commande du 25/10/2022',
#   'order_date': '25/10/2022',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Les skis correspondent à la qualité annoncée par le site.'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/12455-ski-occasion-junior-wedze-team-onebreaker-fixations.html',
#   'client_name': 'Client anonymepublié le 03/09/2022suite à une commande du 28/08/2022',
#   'order_date': '28/08/2022',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Conforme au descriptif'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/14146-ski-occasion-junior-roxy-girly-coeur-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/14272-ski-occasion-junior-head-xrc-50-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/16851-ski-occasion-junior-tecnopro-flyte-jr-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/17002-ski-occasion-junior-volkl-rtm-jr-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/18613-ski-occasion-junior-fischer-stunner-fixations.html',
#   'client_name': 'Yoann B.publié le 18/02/2024suite à une commande du 07/02/2024',
#   'order_date': '07/02/2024',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Correspond aux attentes'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/12473-ski-occasion-junior-volkl-racetiger-sl-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/12493-ski-occasion-junior-head-supershape-era-20-fixations.html',
#   'client_name': 'Client anonymepublié le 19/10/2022suite à une commande du 07/10/2022',
#   'order_date': '07/10/2022',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Ski impeccable, semelle et cares parfaites. Fixations un peu usées au niveau des plastiques mais rapport qualité-prix excellent.'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/12566-ski-occasion-junior-dynastar-team-course-wc-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/14184-ski-occasion-junior-elan-race-rc-waveflex-fixations.html',
#   'client_name': 'Joris K.publié le 17/12/2022suite à une commande du 04/12/2022',
#   'order_date': '04/12/2022',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Pas nouveau mais bonne condition.'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/14324-ski-occasion-junior-rossignol-hero-junior-pro-multi-event-fixations.html',
#   'client_name': 'Paul F.publié le 12/09/2023suite à une commande du 31/08/2023',
#   'order_date': '31/08/2023',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'conforme description'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/14557-ski-occasion-junior-dynastar-team-course-wc-fixations.html',
#   'client_name': 'Jessy S.publié le 21/02/2024suite à une commande du 22/01/2024',
#   'order_date': '22/01/2024',
#   'comment_date': None,
#   'rating': '2/5',
#   'comment': 'Correctement classé C car le Matériel est en bon état mais a beaucoup de rayures'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/16441-ski-occasion-junior-head-team-supershape-era-20-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/18213-ski-occasion-junior-blizzard-racing-gs-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/18266-ski-occasion-junior-fischer-rc4-worldcup-gs-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/18309-ski-occasion-junior-volkl-racetiger-gs-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-de-rando-occasion-et-fin-de-serie/18871-ski-occasion-rando-pack-dynastar-cham-alti-85-fixation-look-hm-12.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/17488-ski-de-fond-occasion-junior-salomon-skin-race-fixation-sns-access.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/16862-ski-occasion-lacroix-lx-gravity-fixations.html',
#   'client_name': None,
#   'order_date': None,
#   'comment_date': None,
#   'rating': None,
#   'comment': None},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/16493-ski-occasion-rossignol-react-8-fixations.html',
#   'client_name': 'Nadir B.publié le 16/11/2023suite à une commande du 08/11/2023',
#   'order_date': '08/11/2023',
#   'comment_date': None,
#   'rating': '4/5',
#   'comment': 'Correct'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/11458-ski-occasion-junior-rossignol-radical-j-fixations.html',
#   'client_name': 'Client anonymepublié le 02/11/2022suite à une commande du 24/10/2022',
#   'order_date': '24/10/2022',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Ensemble raisonnable'},
#  {'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/14128-ski-occasion-junior-k2-rosace-fixations.html',
#   'client_name': 'Florian W.publié le 29/10/2023suite à une commande du 15/10/2023',
#   'order_date': '15/10/2023',
#   'comment_date': None,
#   'rating': '5/5',
#   'comment': 'Très bien.'}]

# %% [markdown]
# ### Convert result into a Dataframe

# %%
df = pd.DataFrame(all_product_details)

# %%
df.columns
# Out:
# Index(['link', 'client_name', 'order_date', 'comment_date', 'rating',
#        'comment'],
#       dtype='object')

# %% [markdown]
# ## Data cleaning and preparation

# %%
# Apply extraction on 'client_name' column
df[['client_name_clean', 'published_date']] = df['client_name'].str.extract(r'^(.*?)publié le (\d{2}/\d{2}/\d{4})')

# Convert extracted date strings to datetime
df['published_date'] = pd.to_datetime(df['published_date'], format='%d/%m/%Y', errors='coerce')

# Show results to check
print(df[['client_name_clean', 'published_date']].head())
df
# Out:
#   client_name_clean published_date
# 0        FERNAND L.     2024-04-17
# 1           Peio A.     2023-11-11
# 2               NaN            NaT
# 3        Etienne H.     2023-01-30
# 4          Marie D.     2024-02-25
#                                                   link  \
# 0    https://freeglisse.com/fr/ski-occasion-adulte-...
# 1    https://freeglisse.com/fr/ski-occasion-adulte-...
# 2    https://freeglisse.com/fr/ski-de-fond-occasion...
# 3    https://freeglisse.com/fr/ski-de-fond-occasion...
# 4    https://freeglisse.com/fr/ski-occasion-femme-l...
# ..                                                 ...
# 164  https://freeglisse.com/fr/ski-de-fond-occasion...
# 165  https://freeglisse.com/fr/ski-occasion-adulte-...
# 166  https://freeglisse.com/fr/ski-occasion-adulte-...
# 167  https://freeglisse.com/fr/ski-occasion-junior-...
# 168  https://freeglisse.com/fr/ski-occasion-junior-...
#
#                                            client_name  order_date  \
# 0    FERNAND L.publié le 17/04/2024suite à une comm...  09/04/2024
# 1    Peio A.publié le 11/11/2023suite à une command...  01/11/2023
# 2                                                 None        None
# 3    Etienne H.publié le 30/01/2023suite à une comm...  16/01/2023
# 4    Marie D.publié le 25/02/2024suite à une comman...  04/02/2024
# ..                                                 ...         ...
# 164                                               None        None
# 165                                               None        None
# 166  Nadir B.publié le 16/11/2023suite à une comman...  08/11/2023
# 167  Client anonymepublié le 02/11/2022suite à une ...  24/10/2022
# 168  Florian W.publié le 29/10/2023suite à une comm...  15/10/2023
#
#     comment_date rating                                            comment  \
# 0           None    5/5  Hormis le problème de fixations après avoir pr...
# 1           None    4/5                                       good cuality
# 2           None   None                                               None
# 3           None    4/5  Je n'ai pas encore pu les tester car pas de ch...
# 4           None    5/5           Etat du produit conforme à mes attentes!
# ..           ...    ...                                                ...
# 164         None   None                                               None
# 165         None   None                                               None
# 166         None    4/5                                            Correct
# 167         None    5/5                               Ensemble raisonnable
# 168         None    5/5                                         Très bien.
#
#     client_name_clean published_date
# 0          FERNAND L.     2024-04-17
# 1             Peio A.     2023-11-11
# 2                 NaN            NaT
# 3          Etienne H.     2023-01-30
# 4            Marie D.     2024-02-25
# ..                ...            ...
# 164               NaN            NaT
# 165               NaN            NaT
# 166          Nadir B.     2023-11-16
# 167    Client anonyme     2022-11-02
# 168        Florian W.     2023-10-29
#
# [169 rows x 8 columns]

# %%
df = df.drop(columns='client_name')

# %%
df = df.rename(columns={'client_name_clean': 'client_name'})

# %%
df = df.drop(columns='comment_date')

# %%
# Set the columns you want to check for empty values
columns_to_check = ['order_date', 'rating', 'comment', 'client_name', 'published_date']

# Use dropna method with 'how' argument set to 'all' to remove rows
# where all columns listed are NaN
df = df.dropna(subset=columns_to_check, how='all')

# %%
# The function to shorten URLs
def shorten_url(url):
    # Find the part of the URL to keep (up to the second '-')
    match = re.match(r"(https://freeglisse.com/fr/.+?/\d+)-", url)
    if match:
        # Return the part of the URL that precedes the unnecessary sequence
        return match.group(1)
    else:
        # If the pattern is not found, return the original URL
        return url

# Apply the function to the 'link' column of the dataframe
df['link'] = df['link'].apply(shorten_url)

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='%d/%m/%Y', errors='coerce')

# %%
columns = ['link', 'client_name', 'comment', 'rating', 'order_date', 'published_date']

# %%
df = df[columns]

# %%
df['days_difference'] = (df['published_date'] - df['order_date']).dt.days

# %%
df.head()
# Out:
#                                                 link  client_name  \
# 0  https://freeglisse.com/fr/ski-occasion-adulte-...   FERNAND L.
# 1  https://freeglisse.com/fr/ski-occasion-adulte-...      Peio A.
# 2  https://freeglisse.com/fr/ski-de-fond-occasion...   Etienne H.
# 3  https://freeglisse.com/fr/ski-occasion-femme-l...     Marie D.
# 4  https://freeglisse.com/fr/ski-occasion-junior-...  Delphine D.
#
#                                              comment rating order_date  \
# 0  Hormis le problème de fixations après avoir pr...    5/5 2024-04-09
# 1                                       good cuality    4/5 2023-11-01
# 2  Je n'ai pas encore pu les tester car pas de ch...    4/5 2023-01-16
# 3           Etat du produit conforme à mes attentes!    5/5 2024-02-04
# 4      skis en bon état, peu utilisés, assez rapides    4/5 2024-03-29
#
#   published_date  days_difference
# 0     2024-04-17                8
# 1     2023-11-11               10
# 2     2023-01-30               14
# 3     2024-02-25               21
# 4     2024-04-09               11

# %%
df.dtypes
# Out:
# link                       object
# client_name                object
# comment                    object
# rating                     object
# order_date         datetime64[ns]
# published_date     datetime64[ns]
# days_difference             int64
# dtype: object

# %%
df['rating'] = df['rating'].str[0].astype(int)

# %%
df.head()
# Out:
#                                                 link  client_name  \
# 0  https://freeglisse.com/fr/ski-occasion-adulte-...   FERNAND L.
# 1  https://freeglisse.com/fr/ski-occasion-adulte-...      Peio A.
# 2  https://freeglisse.com/fr/ski-de-fond-occasion...   Etienne H.
# 3  https://freeglisse.com/fr/ski-occasion-femme-l...     Marie D.
# 4  https://freeglisse.com/fr/ski-occasion-junior-...  Delphine D.
#
#                                              comment  rating order_date  \
# 0  Hormis le problème de fixations après avoir pr...       5 2024-04-09
# 1                                       good cuality       4 2023-11-01
# 2  Je n'ai pas encore pu les tester car pas de ch...       4 2023-01-16
# 3           Etat du produit conforme à mes attentes!       5 2024-02-04
# 4      skis en bon état, peu utilisés, assez rapides       4 2024-03-29
#
#   published_date  days_difference
# 0     2024-04-17                8
# 1     2023-11-11               10
# 2     2023-01-30               14
# 3     2024-02-25               21
# 4     2024-04-09               11

# %% [markdown]
# ## Export datas in CSV file

# %%
df.to_csv('reviews.csv')
