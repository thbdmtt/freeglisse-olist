# %% [markdown]
# # Main Freeglisse Scrapping Code

# %% [markdown]
# ## Setup and Configuration

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import re

# %% [markdown]
# ## Data collection process

# %% [markdown]
# ### Function to get all URLs products

# %%
def get_all_product_urls(base_url):
    all_product_urls = []
    current_page = 1
    while True:
        # Build the current page URL by adding the pagination parameter
        url = f"{base_url}?page={current_page}"
        response = requests.get(url)
        # Break the loop if the page request was unsuccessful
        if response.status_code != 200:
            break 

        soup = BeautifulSoup(response.content, 'html.parser')
        products = soup.find_all('div', class_='product')

        # Find the URL for each product and add it to the list
        page_product_urls = [p.find('a')['href'] for p in products if p.find('a')]
        if not page_product_urls:
            break  # Stop if no product URLs are found on the page

        all_product_urls.extend(page_product_urls)

        # Check if there is a next page
        next_button = soup.find('a', rel='next')
        if not next_button or 'disabled' in next_button.get('class', []):
            break  # Stop if there is no 'next' button or if it's disabled
        
        current_page += 1  # Increment the page number
        
    return all_product_urls


# URL of the first page of products
base_url = 'https://freeglisse.com/fr/12-ski-occasion'
product_urls = get_all_product_urls(base_url)

# %%
def scrape_product_reviews(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    reviews = []
    reviews_container = soup.find_all('div', class_='netreviews_review_part')
    for review in reviews_container:
        comment = review.find('p', class_='netreviews_customer_review').text.strip()
        reviews.append(comment)
    return reviews

# %% [markdown]
# ### Function to extract all datas we need of a single page

# %%
def scrape_product_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract canonical link
    canonical_link = soup.find('link', rel='canonical')['href']

    # Extract reference
    reference = soup.find('label', class_='label title-cate').find_next('span').text

    # Extract title
    title = soup.find('h1', class_='h1 product-detail-name').text
    
    # Extract the brand from the 'alt' attribute of the img
    brand_tag = soup.find('img', class_='img img-thumbnail manufacturer-logo')
    brand = brand_tag['alt'] if brand_tag else None

    # Extract the price excluding taxes
    pretax_price_meta = soup.find('meta', property='product:pretax_price:amount')
    pretax_price = pretax_price_meta['content'] if pretax_price_meta else None

    # Extract usual price and current price
    regular_price_tag = soup.find('span', class_='regular-price')
    current_price = soup.find('span', class_='current-price-value').text.strip().replace('\xa0', '')

    # Extract availability information
    available = soup.find('span', id='availability_message').text

    # Extract qualities
    qualities = [span.text for span in soup.find_all('span', class_='radio-label') 
                if not span.find_previous_sibling('input', type='radio').has_attr('disabled')]

    # Extract product weight
    product_weight_meta = soup.find('meta', property='product:weight:value')
    product_weight = product_weight_meta['content'] if product_weight_meta else None

    # Extract product reviews
    product_reviews = scrape_product_reviews(url)
    
    # Extract the number given by stars
    reviews_count_1_star = soup.find('span', class_='netreviews_rate_total1').text.strip() if soup.find('span', class_='netreviews_rate_total1') else '0'
    reviews_count_2_stars = soup.find('span', class_='netreviews_rate_total2').text.strip() if soup.find('span', class_='netreviews_rate_total2') else '0'
    reviews_count_3_stars = soup.find('span', class_='netreviews_rate_total3').text.strip() if soup.find('span', class_='netreviews_rate_total3') else '0'
    reviews_count_4_stars = soup.find('span', class_='netreviews_rate_total4').text.strip() if soup.find('span', class_='netreviews_rate_total4') else '0'
    reviews_count_5_stars = soup.find('span', class_='netreviews_rate_total5').text.strip() if soup.find('span', class_='netreviews_rate_total5') else '0'

    # Extract the general note
    note_generale = None
    note_generale_tag = soup.find('p', class_='netreviews_note_generale')
    if note_generale_tag:
        note_generale_text = note_generale_tag.text.strip()
        if note_generale_text:
            note_generale = note_generale_text.split()[0] + "/5"

    # Extract the number of reviews
    nombre_avis = None
    review_count_tag = soup.find('span', id='reviewCount')
    if review_count_tag:
        review_count_text = review_count_tag.text.strip()
        if re.match(r'^\d+$', review_count_text):
            nombre_avis = int(review_count_text)

    # Extract product details
    product_details = {}
    details = soup.find_all(['dt', 'dd'])
    for i in range(0, len(details), 2):
        if details[i].get('class', [''])[0] == 'name' and details[i + 1].get('class', [''])[0] == 'value':
            product_details[details[i].text.strip()] = details[i + 1].text.strip()

    # Extract URL from first product image
    image_urls_tag = soup.find('img', class_='img img-thumb')
    image_urls = image_urls_tag['src'] if image_urls_tag else None


    # Build and return a dictionary of product information
    return {
        'title': title,
        'brand': brand,
        'regular_price': regular_price_tag,
        'current_price': current_price,
        'details': product_details,
        'available': available,
        'reference': reference,
        'qualities': qualities,
        'link': canonical_link,
        'weight': product_weight,
        'general_rate': note_generale,
        'nb_ratings': nombre_avis,
        'reviews': product_reviews,
        'image_urls': image_urls,
        'pretax_price': pretax_price,
        'reviews_count_1_star': reviews_count_1_star,
        'reviews_count_2_stars': reviews_count_2_stars,
        'reviews_count_3_stars': reviews_count_3_stars,
        'reviews_count_4_stars': reviews_count_4_stars,
        'reviews_count_5_stars': reviews_count_5_stars,
    }

# %% [markdown]
# ### Extract datas of all pages

# %%
# URL of the first page of the products
base_url = 'https://freeglisse.com/fr/12-ski-occasion'
product_urls = get_all_product_urls(base_url)

# List to store details of all products
all_product_details = []

# Browse each product URL and retrieve details
for url in product_urls:
    details = scrape_product_page(url)
    all_product_details.append(details)

all_product_details
# Out:
# [{'title': 'Ski occasion Rossignol Sender 104 Ti 2023  + Fixations',
#   'brand': 'Rossignol',
#   'regular_price': <span class="regular-price">419,00 €</span>,
#   'current_price': '335,20€',
#   'details': {'Type': 'Freeride',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Performant',
#    'Coloris': 'Gris',
#    'Utilisateur - Configurateur': 'Freerideur adulte',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion freeride'},
#   'available': 'Disponible',
#   'reference': '18916_m27',
#   'qualities': ['Qualité A',
#    '164 cm',
#    '172 cm',
#    '178 cm',
#    '186 cm',
#    'Qualité A',
#    '164 cm',
#    '172 cm',
#    '178 cm',
#    '186 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18916-ski-occasion-rossignol-sender-104-ti-2023-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '5/5',
#   'nb_ratings': 1,
#   'reviews': ["Hormis le problème de fixations après avoir pris le soins de les lustré préparé les cares et fartage la notation qualité A n'ai pas mis en  défaut."],
#   'image_urls': 'https://freeglisse.com/70892-small_default/ski-occasion-rossignol-sender-104-ti-2023-fixations.jpg',
#   'pretax_price': '279.333334',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '1'},
#  {'title': 'Ski occasion Rossignol Sender 94 Ti 2023  + Fixations',
#   'brand': 'Rossignol',
#   'regular_price': <span class="regular-price">359,00 €</span>,
#   'current_price': '287,20€',
#   'details': {'Type': 'Freeride',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Performant',
#    'Coloris': 'Noir',
#    'Utilisateur - Configurateur': 'Freerideur adulte',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion freeride'},
#   'available': 'Disponible',
#   'reference': '18915_i26',
#   'qualities': ['Qualité A',
#    '156 cm',
#    '164 cm',
#    '172 cm',
#    'Qualité A',
#    '156 cm',
#    '164 cm',
#    '172 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-freeride-et-freestyle/18915-ski-occasion-rossignol-sender-94-ti-2023-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4/5',
#   'nb_ratings': 1,
#   'reviews': ['good cuality'],
#   'image_urls': 'https://freeglisse.com/70897-small_default/ski-occasion-rossignol-sender-94-ti-2023-fixations.jpg',
#   'pretax_price': '239.333334',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '1',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski de fond occasion Rossignol LTS Junior + fixation SNS Profil',
#   'brand': 'Rossignol',
#   'regular_price': None,
#   'current_price': '19,00€',
#   'details': {'Type': 'Alternatif',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Loisir',
#    'Coloris': 'Violet',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski de fond occasion alternatif norme SNS'},
#   'available': 'Disponible',
#   'reference': '18974_mz_l18_violet',
#   'qualities': ['Qualité C',
#    '150 cm',
#    '160 cm',
#    '170 cm',
#    'Qualité C',
#    '150 cm',
#    '160 cm',
#    '170 cm'],
#   'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18974-ski-de-fond-occasion-rossignol-lts-junior-fixation-sns-profil.html',
#   'weight': '4.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': None,
#   'pretax_price': '15.833333',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski de fond occasion Toutes marques + fixation SNS Profil',
#   'brand': 'Toutes marques',
#   'regular_price': None,
#   'current_price': '15,00€',
#   'details': {'Type': 'Alternatif',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir',
#    'Coloris': 'Blanc',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski de fond occasion alternatif norme SNS'},
#   'available': 'Disponible',
#   'reference': '15468_mz_l20',
#   'qualities': ['Qualité C',
#    '140 cm',
#    '150 cm',
#    '160 cm',
#    '170 cm',
#    'Qualité C',
#    '36',
#    '42',
#    'Qualité C'],
#   'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/15468-ski-de-fond-occasion-toutes-marques-fixation-sns-profil.html',
#   'weight': '4.000000',
#   'general_rate': '4.8/5',
#   'nb_ratings': 10,
#   'reviews': ["Je n'ai pas encore pu les tester car pas de chaussure dispo a la vente pour la pointure. Mais les écailles semblent encore en bon etat",
#    'parfait, conforme à la description',
#    'Conforme',
#    'Superbe etat',
#    'Bon rapport qualité/prix',
#    'Conforme à la description, super',
#    'Pas déçue bien',
#    'Super pour le prix, ils ont déjà fait un tour de piste ce WE',
#    "Produit conforme à la description. Livraison sous 3 jours. Ma fille peut s'initier avec joie au ski de fond pour un prix tres correct. Parfait !",
#    'Conforme'],
#   'image_urls': 'https://freeglisse.com/43792-small_default/ski-de-fond-occasion-toutes-marques-fixation-sns-profil.jpg',
#   'pretax_price': '12.5',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '2',
#   'reviews_count_5_stars': '8'},
#  {'title': 'Ski occasion Rossignol Nova 6 + fixations',
#   'brand': 'Rossignol',
#   'regular_price': None,
#   'current_price': '169,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Femme',
#    'Niveau': 'Loisir',
#    'Coloris': 'Violet',
#    'Utilisateur - Configurateur': 'une femme',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion femme loisir'},
#   'available': 'Disponible',
#   'reference': '18890_l36',
#   'qualities': ['Qualité A',
#    'Qualité B',
#    'Qualité C',
#    '149 cm',
#    'Qualité A',
#    'Qualité B',
#    'Qualité C',
#    '149 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-femme-loisir/18890-ski-occasion-rossignol-nova-6-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '3.2/5',
#   'nb_ratings': 5,
#   'reviews': ['Etat du produit conforme à mes attentes!',
#    'Gewählte Qualiät war C - Oberseite schon einige Abplatzer; Laufflächen und Kanten aber okay. Gutes Preis-Lestungs-Verhältnis',
#    "Des skis pas chers c'est sûr mais quel état pitoyable !! Ok j'ai choisi categorie C et ça ne m'empêchera pas de skier mais qd-même !! A ce niveau c'est plutôt categorie Z !!! Il manque carrément  des morceaux sur le dessus des skis !! Une photo précise de l'état réel de la marchandise devrait être obligatoire.... bref... super déçue !",
#    'Très bien',
#    'Pour des skis de 2022 pas en très bon état et le fartage est très moyen'],
#   'image_urls': 'https://freeglisse.com/70606-small_default/ski-occasion-rossignol-nova-6-fixations.jpg',
#   'pretax_price': '140.833333',
#   'reviews_count_1_star': '2',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '1',
#   'reviews_count_5_stars': '2'},
#  {'title': 'Ski occasion junior toutes marques à 29 € + Fixations',
#   'brand': 'Toutes marques',
#   'regular_price': None,
#   'current_price': '29,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Loisir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior pas cher'},
#   'available': 'Disponible',
#   'reference': '18084_a54',
#   'qualities': ['Qualité B',
#    '100 cm',
#    '110 cm',
#    '117 cm',
#    '120 cm',
#    '130 cm',
#    '131 cm',
#    '136 cm',
#    '137 cm',
#    '140 cm',
#    '145 cm',
#    '147 cm',
#    '150 cm',
#    'Qualité B',
#    '100 cm',
#    '110 cm',
#    '117 cm',
#    '120 cm',
#    '130 cm',
#    '131 cm',
#    '136 cm',
#    '137 cm',
#    '140 cm',
#    '145 cm',
#    '147 cm',
#    '150 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/18084-ski-occasion-junior-toutes-marques-a-29-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4.5/5',
#   'nb_ratings': 2,
#   'reviews': ['skis en bon état, peu utilisés, assez rapides',
#    'Ancien mais ok'],
#   'image_urls': None,
#   'pretax_price': '24.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '1',
#   'reviews_count_5_stars': '1'},
#  {'title': 'Ski occasion junior toutes marques à 19 € + Fixations',
#   'brand': 'Toutes marques',
#   'regular_price': None,
#   'current_price': '19,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Loisir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior pas cher'},
#   'available': 'Disponible',
#   'reference': '1795_a60',
#   'qualities': ['Qualité B',
#    '100 cm',
#    '110 cm',
#    '115 cm',
#    '118 cm',
#    '120 cm',
#    '130 cm',
#    '135 cm',
#    '150 cm',
#    'Qualité B',
#    '100 cm',
#    '110 cm',
#    '115 cm',
#    '118 cm',
#    '120 cm',
#    '130 cm',
#    '135 cm',
#    '150 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/1795-ski-occasion-junior-toutes-marques-a-19-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4.2/5',
#   'nb_ratings': 17,
#   'reviews': ['impeccable',
#    'Conforme',
#    'Skis propres avec usure normale',
#    'Conforme au prix.',
#    'Bien',
#    'Skis réglé pour la chaussure, fartage est déjà fait.',
#    'Ski moyen',
#    'Bon matériel !!',
#    "Agréablement surpris, pour le prix franchement c'est très correct.",
#    "Bon produit fatigué au niveaux esthétique mais on s'en doutais vu que c'c'est du ski de location",
#    'Semelles en très bon état',
#    "Très bien c'est complétement adapté pour débuter et d'un très bon rapport qualité prix . Je recommande.\r\nAntoine",
#    'Mauvais état, Très déçue',
#    'Les ski sont impeccables pour ce prix.',
#    'Tres bien',
#    'Fartage un peu rapide et ski abîmé (précisé dans la description)',
#    "Se sont des skis d'occasions donc un peu abimés"],
#   'image_urls': 'https://freeglisse.com/3608-small_default/ski-occasion-junior-toutes-marques-a-19-fixations.jpg',
#   'pretax_price': '15.833333',
#   'reviews_count_1_star': '1',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '2',
#   'reviews_count_4_stars': '5',
#   'reviews_count_5_stars': '9'},
#  {'title': 'Ski de fond occasion Toutes marques  + fixation vieux sns',
#   'brand': 'Toutes marques',
#   'regular_price': <span class="regular-price ap5-pack-product-original-price-value">20,00 €</span>,
#   'current_price': '9,00€',
#   'details': {'Type': 'Alternatif',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Débutant',
#    'Coloris': 'Blanc',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski de fond occasion alternatif norme SNS'},
#   'available': 'Disponible',
#   'reference': '15483_mz_k17',
#   'qualities': ['Qualité C',
#    '140 cm',
#    '150 cm',
#    'Qualité C',
#    '140 cm',
#    '150 cm'],
#   'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/15483-ski-de-fond-occasion-toutes-marques-fixation-vieux-sns.html',
#   'weight': '4.000000',
#   'general_rate': '4.6/5',
#   'nb_ratings': 5,
#   'reviews': ['Etat correct',
#    'bien',
#    'Parfait',
#    'Tbien',
#    'Le matériel est en très bon état.'],
#   'image_urls': 'https://freeglisse.com/43793-small_default/ski-de-fond-occasion-toutes-marques-fixation-vieux-sns.jpg',
#   'pretax_price': '7.5',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '2',
#   'reviews_count_5_stars': '3'},
#  {'title': 'Ski de fond occasion Toutes marques + fixation SNS Profil',
#   'brand': 'Toutes marques',
#   'regular_price': None,
#   'current_price': '19,00€',
#   'details': {'Type': 'Alternatif',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir',
#    'Coloris': 'Gris',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski de fond occasion alternatif norme SNS'},
#   'available': 'Disponible',
#   'reference': '18999_mz_l08',
#   'qualities': ['Qualité C',
#    '170 cm',
#    '180 cm',
#    '190 cm',
#    'Qualité C',
#    '36',
#    '42',
#    'Qualité C'],
#   'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18999-ski-de-fond-occasion-toutes-marques-fixation-sns-profil.html',
#   'weight': '4.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': None,
#   'pretax_price': '15.833333',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski junior Rossignol Star Wars occasion + fixations',
#   'brand': 'Rossignol',
#   'regular_price': None,
#   'current_price': '69,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Débutant',
#    'Coloris': 'Bleu',
#    'Utilisateur - Configurateur': 'un junior',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior loisir'},
#   'available': 'Disponible',
#   'reference': '14329_a03_blancbleu',
#   'qualities': ['Qualité A', '110 cm', 'Qualité A', '110 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/14329-ski-junior-rossignol-star-wars-occasion-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4.4/5',
#   'nb_ratings': 9,
#   'reviews': ['Sehr guter Zustand',
#    'presques neufs !!',
#    'Livraison super rapide.\r\nUn peu déçu de l état du matériel par rapport aux photos du site \r\nJe pensais qu en cat a le matériel serait en meilleur état.\r\nJe n imagine meme pas la cat b ou c...\r\nAprès il ne.faut oublier que c est de l occasion',
#    'Skis correspondant au descriptif',
#    "Paire de ski commandée qualité A, or l'un des skis était rayé sur toute la longueur de la semelle (dû à un caillou très certainement).\r\nMalheureusement, c'était ma 1ère commande auprès de ce site et ce sera la dernière.\r\nJe ne le conseille pas.",
#    'Super etat',
#    'Très bon ski, fixations nickel',
#    'Bon état...',
#    'As expected.'],
#   'image_urls': 'https://freeglisse.com/37832-small_default/ski-junior-rossignol-star-wars-occasion-fixations.jpg',
#   'pretax_price': '57.5',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '1',
#   'reviews_count_3_stars': '1',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '7'},
#  {'title': 'Ski occasion Femme toutes marques tous modèles à 29€ + fixations',
#   'brand': 'Toutes marques',
#   'regular_price': <span class="regular-price ap5-pack-product-original-price-value">62,00 €</span>,
#   'current_price': '29,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Femme',
#    'Niveau': 'Loisir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion femme pas cher'},
#   'available': 'Disponible',
#   'reference': '16352_q23',
#   'qualities': ['Qualité C',
#    '140 cm',
#    '146 cm',
#    '147 cm',
#    '150 cm',
#    '153 cm',
#    '154 cm',
#    '156 cm',
#    '159 cm',
#    '160 cm',
#    '162 cm',
#    '163 cm',
#    '165 cm',
#    '168 cm',
#    '170 cm',
#    '172 cm',
#    'Qualité C',
#    '140 cm',
#    '146 cm',
#    '147 cm',
#    '150 cm',
#    '153 cm',
#    '154 cm',
#    '156 cm',
#    '159 cm',
#    '160 cm',
#    '162 cm',
#    '163 cm',
#    '165 cm',
#    '168 cm',
#    '170 cm',
#    '172 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-femme-pas-cher/16352-ski-occasion-femme-toutes-marques-tous-modeles-a-29-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4/5',
#   'nb_ratings': 10,
#   'reviews': ['no lo puedo valorar',
#    'super rapport qualité prix pour débuter',
#    'Super achat pour 29€ je m’attendais à des skis beaucoup plus animés. Ils sont en bon état. Pour un prix défiant toute concurrence. Avec les frais de ports deux fois moins cher qu’une semaine de location pour des skis eco sans chaussures.',
#    'Parfait',
#    "Pour un état de catégorie A, j'ai reçu des skis plutôt de catégorie C. Ils ne veulent pas admettre",
#    'parfait',
#    'Super',
#    'Super dans un état très correct pour son prix',
#    'Pas encore utilisé mais les skis sont en état correct vu le prix',
#    "29€ LA PAIRE DE SKIS ROSSIGNOL EN B.E PRETS A SKIER AVEC LES CHAUSSURES SALOMON EN T.B.E A 25€ ET DES BATONS A 6€ SOIT MOINS QU' 1 SEMAINE EN LOCATION= SUPER RENTABLE SACHANT QU ON VA TS LES ANS AU SKI!  MERCI A VOUS"],
#   'image_urls': 'https://freeglisse.com/47729-small_default/ski-occasion-femme-toutes-marques-tous-modeles-a-29-fixations.jpg',
#   'pretax_price': '24.166667',
#   'reviews_count_1_star': '1',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '1',
#   'reviews_count_4_stars': '4',
#   'reviews_count_5_stars': '4'},
#  {'title': 'Ski occasion Salomon Tous Modèles à 29€ + fixations',
#   'brand': 'Salomon',
#   'regular_price': None,
#   'current_price': '29,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion adulte pas cher'},
#   'available': 'Disponible',
#   'reference': '13078_q01_q03',
#   'qualities': ['Qualité C',
#    '155 cm',
#    '156 cm',
#    '158 cm',
#    '160 cm',
#    '161 cm',
#    '166 cm',
#    '170 cm',
#    '174 cm',
#    '175 cm',
#    '178 cm',
#    '180 cm',
#    'Qualité C',
#    '155 cm',
#    '156 cm',
#    '158 cm',
#    '160 cm',
#    '161 cm',
#    '166 cm',
#    '170 cm',
#    '174 cm',
#    '175 cm',
#    '178 cm',
#    '180 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13078-ski-occasion-salomon-tous-modeles-a-29-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4.8/5',
#   'nb_ratings': 8,
#   'reviews': ['Surpris par le bon état des skis',
#    'Parfait',
#    'parfait',
#    'Bravo, conforme à notre attente',
#    'good',
#    'Matériel présentant des défauts esthétique mais conforme à la description. Parfait pour le prix',
#    'Une belle surprise. Matériel performant et en bon état.',
#    'bon prix'],
#   'image_urls': 'https://freeglisse.com/32207-small_default/ski-occasion-salomon-tous-modeles-a-29-fixations.jpg',
#   'pretax_price': '24.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '2',
#   'reviews_count_5_stars': '6'},
#  {'title': 'Ski occasion Dynastar SPEED ZONE 4x4 78 + fixations',
#   'brand': 'Dynastar',
#   'regular_price': <span class="regular-price ap5-pack-product-original-price-value">232,00 €</span>,
#   'current_price': '199,00€',
#   'details': {'Type': 'All mountain',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Débutant',
#    'Coloris': 'Gris',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion adulte all mountain'},
#   'available': 'Disponible',
#   'reference': '18284_g32',
#   'qualities': ['Qualité A',
#    'Qualité B',
#    '171 cm',
#    'Qualité A',
#    'Qualité B',
#    '171 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18284-ski-occasion-dynastar-speed-zone-4x4-78-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/67614-small_default/ski-occasion-dynastar-speed-zone-4x4-78-fixations.jpg',
#   'pretax_price': '165.833333',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion junior Dynastar Team speed  + Fixations',
#   'brand': 'Dynastar',
#   'regular_price': None,
#   'current_price': '59,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Loisir sport',
#    'Coloris': 'Blanc',
#    'Utilisateur - Configurateur': 'un junior',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior loisir'},
#   'available': 'Disponible',
#   'reference': '14533_b72',
#   'qualities': ['Qualité A', '130 cm', 'Qualité A', '130 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/14533-ski-occasion-junior-dynastar-team-speed-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4.6/5',
#   'nb_ratings': 9,
#   'reviews': ['Conforme à ce qui est annoncé',
#    'Producto conforme a la descripción y correctamente preparado',
#    'à tester mais visuellement très bien',
#    'Bien',
#    '.super',
#    'Skis en état très moyen.',
#    'Bon état et bien préparé',
#    'Conforme',
#    'Comforme à la description'],
#   'image_urls': 'https://freeglisse.com/35611-small_default/ski-occasion-junior-dynastar-team-speed-fixations.jpg',
#   'pretax_price': '49.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '1',
#   'reviews_count_4_stars': '2',
#   'reviews_count_5_stars': '6'},
#  {'title': 'Ski de fond occasion Rossignol Progress + fixaxion SNS profil',
#   'brand': 'Rossignol',
#   'regular_price': None,
#   'current_price': '19,00€',
#   'details': {'Type': 'Alternatif',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir',
#    'Coloris': 'Bleu',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski de fond occasion alternatif norme SNS'},
#   'available': 'Disponible',
#   'reference': '18972_mz_l16_bleu',
#   'qualities': ['Qualité C',
#    '130 cm',
#    '140 cm',
#    '150 cm',
#    'Qualité C',
#    '130 cm',
#    '140 cm',
#    '150 cm'],
#   'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/18972-ski-de-fond-occasion-rossignol-progress-fixaxion-sns-profil.html',
#   'weight': '4.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': None,
#   'pretax_price': '15.833333',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski de fond occasion Fischer Cruiser Crown + fixation NNN',
#   'brand': 'Fischer',
#   'regular_price': None,
#   'current_price': '75,00€',
#   'details': {'Type': 'Alternatif',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir sport',
#    'Coloris': 'Noir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski de fond occasion alternatif norme NNN'},
#   'available': 'Disponible',
#   'reference': '18914_mz_l02_noir',
#   'qualities': ['Qualité A',
#    'Qualité B',
#    '174 cm',
#    '184 cm',
#    'Qualité A',
#    'Qualité B',
#    '174 cm',
#    '184 cm'],
#   'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-nnn/18914-ski-de-fond-occasion-fischer-cruiser-crown-fixation-nnn.html',
#   'weight': '4.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': None,
#   'pretax_price': '62.5',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Atomic tous modèle à 29€ + fixations',
#   'brand': 'Atomic',
#   'regular_price': None,
#   'current_price': '29,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion adulte pas cher'},
#   'available': 'Disponible',
#   'reference': '13097_q13_q15',
#   'qualities': ['Qualité C',
#    '158 cm',
#    '160 cm',
#    '170 cm',
#    '172 cm',
#    '180 cm',
#    '190 cm',
#    'Qualité C',
#    '158 cm',
#    '160 cm',
#    '170 cm',
#    '172 cm',
#    '180 cm',
#    '190 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13097-ski-occasion-atomic-tous-modele-a-29-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '5/5',
#   'nb_ratings': 1,
#   'reviews': ['Très bon état nous allons les tester le 3 février !!!'],
#   'image_urls': 'https://freeglisse.com/32170-small_default/ski-occasion-atomic-tous-modele-a-29-fixations.jpg',
#   'pretax_price': '24.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '1'},
#  {'title': 'Ski occasion Dynastar Legend X 75 + fixations',
#   'brand': 'Dynastar',
#   'regular_price': None,
#   'current_price': '109,00€',
#   'details': {'Type': 'Polyvalent',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir sport',
#    'Coloris': 'Noir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion adulte loisir'},
#   'available': 'Disponible',
#   'reference': '18536_L06',
#   'qualities': ['Qualité B',
#    '156 cm',
#    '164 cm',
#    '172 cm',
#    'Qualité B',
#    '156 cm',
#    '164 cm',
#    '172 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-loisir/18536-ski-occasion-dynastar-legend-x-75-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/68588-small_default/ski-occasion-dynastar-legend-x-75-fixations.jpg',
#   'pretax_price': '90.833333',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion K2 Thrilluvit 85 + fixations',
#   'brand': 'K2',
#   'regular_price': None,
#   'current_price': '119,00€',
#   'details': {'Type': 'All mountain',
#    'Utilisateur': 'Femme',
#    'Niveau': 'Loisir',
#    'Coloris': 'Bleu',
#    'Utilisateur - Configurateur': 'une femme',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion femme all mountain'},
#   'available': 'Disponible',
#   'reference': '17203_j32',
#   'qualities': ['Qualité B',
#    '156 cm',
#    '163 cm',
#    'Qualité B',
#    '156 cm',
#    '163 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/17203-ski-occasion-k2-thrilluvit-85-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/66100-small_default/ski-occasion-k2-thrilluvit-85-fixations.jpg',
#   'pretax_price': '99.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Dynastar SPEED ZONE 4x4 82 + fixations',
#   'brand': 'Dynastar',
#   'regular_price': None,
#   'current_price': '219,00€',
#   'details': {'Type': 'All mountain',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir sport',
#    'Coloris': 'Blanc',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion adulte all mountain'},
#   'available': 'Disponible',
#   'reference': '18381_i23',
#   'qualities': ['Qualité A',
#    'Qualité B',
#    '164 cm',
#    'Qualité A',
#    'Qualité B',
#    '164 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/18381-ski-occasion-dynastar-speed-zone-4x4-82-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/68062-small_default/ski-occasion-dynastar-speed-zone-4x4-82-fixations.jpg',
#   'pretax_price': '182.5',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Atomic Cloud Q9 + fixations',
#   'brand': 'Atomic',
#   'regular_price': None,
#   'current_price': '299,00€',
#   'details': {'Type': 'All mountain',
#    'Utilisateur': 'Femme',
#    'Niveau': 'Loisir sport',
#    'Coloris': 'Noir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion femme all mountain'},
#   'available': 'Disponible',
#   'reference': '18929_m17',
#   'qualities': ['Qualité A',
#    'Qualité B',
#    '147 cm',
#    'Qualité A',
#    'Qualité B',
#    '147 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/18929-ski-occasion-atomic-cloud-q9-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '5/5',
#   'nb_ratings': 1,
#   'reviews': ['Idem'],
#   'image_urls': 'https://freeglisse.com/71538-small_default/ski-occasion-atomic-cloud-q9-fixations.jpg',
#   'pretax_price': '249.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '1'},
#  {'title': 'Ski FILLE occasion junior toutes marques à 29 € + Fixations',
#   'brand': 'Toutes marques',
#   'regular_price': None,
#   'current_price': '29,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Fille',
#    'Niveau': 'Loisir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior pas cher'},
#   'available': 'Disponible',
#   'reference': '16346_a48',
#   'qualities': ['Qualité B',
#    '100 cm',
#    '110 cm',
#    '117 cm',
#    '120 cm',
#    '130 cm',
#    '154 cm',
#    '158 cm',
#    'Qualité B',
#    '100 cm',
#    '110 cm',
#    '117 cm',
#    '120 cm',
#    '130 cm',
#    '154 cm',
#    '158 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/16346-ski-fille-occasion-junior-toutes-marques-a-29-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/47667-small_default/ski-fille-occasion-junior-toutes-marques-a-29-fixations.jpg',
#   'pretax_price': '24.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Rossignol tous modèle à 29€ + fixations',
#   'brand': 'Rossignol',
#   'regular_price': None,
#   'current_price': '29,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion adulte pas cher'},
#   'available': 'Disponible',
#   'reference': '13090_q11',
#   'qualities': ['Qualité C',
#    '160 cm',
#    '168 cm',
#    '170 cm',
#    '176 cm',
#    '178 cm',
#    'Qualité C',
#    '160 cm',
#    '168 cm',
#    '170 cm',
#    '176 cm',
#    '178 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13090-ski-occasion-rossignol-tous-modele-a-29-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4.3/5',
#   'nb_ratings': 6,
#   'reviews': ['Parfait!',
#    'Superbe',
#    "Matériel conforme au degré d'usure annoncé",
#    'Produit conforme à la commande, la semelle des skis a été refaite, livré rapidement 👍🏻',
#    'bon prix',
#    'super'],
#   'image_urls': 'https://freeglisse.com/32179-small_default/ski-occasion-rossignol-tous-modele-a-29-fixations.jpg',
#   'pretax_price': '24.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '4',
#   'reviews_count_5_stars': '2'},
#  {'title': 'Ski occasion adulte K2 tous modèles à 29€ + Fixations',
#   'brand': 'K2',
#   'regular_price': None,
#   'current_price': '29,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir',
#    'Coloris': 'Noir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion adulte pas cher'},
#   'available': 'Disponible',
#   'reference': '13081_q25',
#   'qualities': ['Qualité C',
#    '159 cm',
#    '160 cm',
#    '163 cm',
#    '167 cm',
#    '174 cm',
#    '181 cm',
#    'Qualité C',
#    '159 cm',
#    '160 cm',
#    '163 cm',
#    '167 cm',
#    '174 cm',
#    '181 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13081-ski-occasion-adulte-k2-tous-modeles-a-29-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4/5',
#   'nb_ratings': 1,
#   'reviews': ['Me semblent bien mais pas essayé. Livraison rapide'],
#   'image_urls': 'https://freeglisse.com/32203-small_default/ski-occasion-adulte-k2-tous-modeles-a-29-fixations.jpg',
#   'pretax_price': '24.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '1',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski FILLE occasion junior toutes marques à 29 € + Fixations',
#   'brand': 'Toutes marques',
#   'regular_price': None,
#   'current_price': '29,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Fille',
#    'Niveau': 'Loisir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior pas cher'},
#   'available': 'Disponible',
#   'reference': '16346_a48',
#   'qualities': ['Qualité B',
#    '100 cm',
#    '110 cm',
#    '117 cm',
#    '120 cm',
#    '130 cm',
#    '154 cm',
#    '158 cm',
#    'Qualité B',
#    '100 cm',
#    '110 cm',
#    '117 cm',
#    '120 cm',
#    '130 cm',
#    '154 cm',
#    '158 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-pas-cher/16346-ski-fille-occasion-junior-toutes-marques-a-29-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/47667-small_default/ski-fille-occasion-junior-toutes-marques-a-29-fixations.jpg',
#   'pretax_price': '24.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Rossignol Strato Edition 2023 + fixations',
#   'brand': 'Rossignol',
#   'regular_price': <span class="regular-price">409,00 €</span>,
#   'current_price': '327,20€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Compétition',
#    'Coloris': 'Noir',
#    'Utilisateur - Configurateur': 'Adulte Performance',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion adulte performance'},
#   'available': 'Disponible',
#   'reference': '18966_f01',
#   'qualities': ['Qualité A',
#    'Qualité B',
#    '157 cm',
#    'Qualité A',
#    'Qualité B',
#    '157 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/18966-ski-occasion-rossignol-strato-edition-2023-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/71620-small_default/ski-occasion-rossignol-strato-edition-2023-fixations.jpg',
#   'pretax_price': '272.666666',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Nordica Navigator 85 + fixations',
#   'brand': 'Nordica',
#   'regular_price': None,
#   'current_price': '59,00€',
#   'details': {'Type': 'All mountain',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir',
#    'Coloris': 'Orange',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion adulte all mountain'},
#   'available': 'Disponible',
#   'reference': '16751_h07',
#   'qualities': ['Qualité C',
#    '158 cm',
#    '172 cm',
#    '179 cm',
#    'Qualité C',
#    '158 cm',
#    '172 cm',
#    '179 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/16751-ski-occasion-nordica-navigator-85-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/51728-small_default/ski-occasion-nordica-navigator-85-fixations.jpg',
#   'pretax_price': '49.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Dynastar tous modèle à 29€ + fixations',
#   'brand': 'Dynastar',
#   'regular_price': None,
#   'current_price': '29,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion adulte pas cher'},
#   'available': 'Disponible',
#   'reference': '13096_q05',
#   'qualities': ['Qualité C',
#    '150 cm',
#    '154 cm',
#    '165 cm',
#    '172 cm',
#    '178 cm',
#    'Qualité C',
#    '150 cm',
#    '154 cm',
#    '165 cm',
#    '172 cm',
#    '178 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13096-ski-occasion-dynastar-tous-modele-a-29-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4.6/5',
#   'nb_ratings': 5,
#   'reviews': ['Matériel un peu vieillot en Dynastar, autant voir sur les autres marques',
#    'Classe C en bon état général.',
#    'Top produit !',
#    'super',
#    'tres rapide tout est ok'],
#   'image_urls': 'https://freeglisse.com/32174-small_default/ski-occasion-dynastar-tous-modele-a-29-fixations.jpg',
#   'pretax_price': '24.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '1',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '4'},
#  {'title': 'Ski occasion Volkl tous modèle à 29€ + fixations',
#   'brand': 'Volkl',
#   'regular_price': None,
#   'current_price': '29,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion adulte pas cher'},
#   'available': 'Disponible',
#   'reference': '13083_q09',
#   'qualities': ['Qualité C',
#    '163 cm',
#    '170 cm',
#    '175 cm',
#    '177 cm',
#    '184 cm',
#    'Qualité C',
#    '163 cm',
#    '170 cm',
#    '175 cm',
#    '177 cm',
#    '184 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13083-ski-occasion-volkl-tous-modele-a-29-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '5/5',
#   'nb_ratings': 1,
#   'reviews': ['Nickel'],
#   'image_urls': 'https://freeglisse.com/32199-small_default/ski-occasion-volkl-tous-modele-a-29-fixations.jpg',
#   'pretax_price': '24.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '1'},
#  {'title': 'Ski occasion Fischer Brilliant My Turn + fixations',
#   'brand': 'Fischer',
#   'regular_price': None,
#   'current_price': '249,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Femme',
#    'Niveau': 'Performant',
#    'Coloris': 'Noir',
#    'Utilisateur - Configurateur': 'une femme',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion femme performance'},
#   'available': 'Disponible',
#   'reference': '15968_n09',
#   'qualities': ['Qualité A',
#    'Qualité B',
#    '145 cm',
#    'Qualité A',
#    'Qualité B',
#    '145 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-femme-performance/15968-ski-occasion-fischer-brilliant-my-turn-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/46140-small_default/ski-occasion-fischer-brilliant-my-turn-fixations.jpg',
#   'pretax_price': '207.5',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Elan tous modèle à 29€ + fixations',
#   'brand': 'Elan',
#   'regular_price': None,
#   'current_price': '29,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion adulte pas cher'},
#   'available': 'Disponible',
#   'reference': '13085_q19',
#   'qualities': ['Qualité C',
#    '152 cm',
#    '160 cm',
#    '176 cm',
#    'Qualité C',
#    '152 cm',
#    '160 cm',
#    '176 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-pas-cher/13085-ski-occasion-elan-tous-modele-a-29-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/32191-small_default/ski-occasion-elan-tous-modele-a-29-fixations.jpg',
#   'pretax_price': '24.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Volkl Secret + fixations',
#   'brand': 'Volkl',
#   'regular_price': None,
#   'current_price': '259,00€',
#   'details': {'Type': 'Freeride',
#    'Utilisateur': 'Femme',
#    'Niveau': 'Performant',
#    'Coloris': 'Noir',
#    'Utilisateur - Configurateur': 'Freerideur adulte',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion freeride'},
#   'available': 'Disponible',
#   'reference': '18418_j13',
#   'qualities': ['Qualité A',
#    '149 cm',
#    '156 cm',
#    '163 cm',
#    'Qualité A',
#    '149 cm',
#    '156 cm',
#    '163 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-freeride/18418-ski-occasion-volkl-secret-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/68241-small_default/ski-occasion-volkl-secret-fixations.jpg',
#   'pretax_price': '215.833333',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion junior Dynastar Slider + Fixations',
#   'brand': 'Dynastar',
#   'regular_price': None,
#   'current_price': '45,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Débutant',
#    'Coloris': 'Blanc',
#    'Utilisateur - Configurateur': 'un junior',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior loisir'},
#   'available': 'Disponible',
#   'reference': '18333_c76',
#   'qualities': ['Qualité B',
#    '116 cm',
#    '128 cm',
#    'Qualité B',
#    '116 cm',
#    '128 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/18333-ski-occasion-junior-dynastar-slider-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/64845-small_default/ski-occasion-junior-dynastar-slider-fixations.jpg',
#   'pretax_price': '37.5',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion junior Head Supershape + fixations',
#   'brand': 'Head',
#   'regular_price': None,
#   'current_price': '45,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Loisir sport',
#    'Coloris': 'Blanc',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior performance'},
#   'available': 'Disponible',
#   'reference': '12512_b51',
#   'qualities': ['Qualité C',
#    '120 cm',
#    '130 cm',
#    'Qualité C',
#    '120 cm',
#    '130 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/12512-ski-occasion-junior-head-supershape-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '5/5',
#   'nb_ratings': 1,
#   'reviews': ["Semelles et carres en bon état c'est le plus important..."],
#   'image_urls': 'https://freeglisse.com/69429-small_default/ski-occasion-junior-head-supershape-fixations.jpg',
#   'pretax_price': '37.5',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '1'},
#  {'title': 'Ski occasion  junior Tecnopro Team Pulse + fixations',
#   'brand': 'Tecnopro',
#   'regular_price': <span class="regular-price ap5-pack-product-original-price-value">98,00 €</span>,
#   'current_price': '55,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Loisir',
#    'Coloris': 'Blanc',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior loisir'},
#   'available': 'Disponible',
#   'reference': '14483_b44',
#   'qualities': ['Qualité A',
#    'Qualité B',
#    '130 cm',
#    'Qualité A',
#    'Qualité B',
#    '130 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/14483-ski-occasion-junior-tecnopro-team-pulse-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4/5',
#   'nb_ratings': 1,
#   'reviews': ['Ski comme prévu sur le site'],
#   'image_urls': 'https://freeglisse.com/35495-small_default/ski-occasion-junior-tecnopro-team-pulse-fixations.jpg',
#   'pretax_price': '45.833333',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '1',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Kastle FX 96 + fixations',
#   'brand': 'Kastle',
#   'regular_price': None,
#   'current_price': '349,00€',
#   'details': {'Type': 'Freeride',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Performant',
#    'Coloris': 'Gris',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion freeride'},
#   'available': 'Disponible',
#   'reference': '18415_j12',
#   'qualities': ['Qualité A',
#    'Qualité B',
#    '172 cm',
#    '180 cm',
#    'Qualité A',
#    'Qualité B',
#    '172 cm',
#    '180 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-freeride/18415-ski-occasion-kastle-fx-96-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/68228-small_default/ski-occasion-kastle-fx-96-fixations.jpg',
#   'pretax_price': '290.833333',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Armada ARV 84 + fixations',
#   'brand': 'Armada',
#   'regular_price': None,
#   'current_price': '189,00€',
#   'details': {'Type': 'Freestyle',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir',
#    'Coloris': 'Gris',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion freestyle'},
#   'available': 'Disponible',
#   'reference': '18382_i24',
#   'qualities': ['Qualité B',
#    '156 cm',
#    '170 cm',
#    'Qualité B',
#    '156 cm',
#    '170 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-freestyle/18382-ski-occasion-armada-arv-84-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/68066-small_default/ski-occasion-armada-arv-84-fixations.jpg',
#   'pretax_price': '157.5',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Dynastar intense 4x4 78 + fixations',
#   'brand': 'Dynastar',
#   'regular_price': None,
#   'current_price': '199,00€',
#   'details': {'Type': 'All mountain',
#    'Utilisateur': 'Femme',
#    'Niveau': 'Loisir sport',
#    'Coloris': 'Bleu',
#    'Utilisateur - Configurateur': 'une femme',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion femme all mountain'},
#   'available': 'Disponible',
#   'reference': '17099_j25',
#   'qualities': ['Qualité A', '164 cm', 'Qualité A', '164 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-femme-all-mountain/17099-ski-occasion-dynastar-intense-4x4-78-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/53965-small_default/ski-occasion-dynastar-intense-4x4-78-fixations.jpg',
#   'pretax_price': '165.833333',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion junior Salomon S Race Jr + fixations',
#   'brand': 'Salomon',
#   'regular_price': None,
#   'current_price': '39,00€',
#   'details': {'Type': 'Racing',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Performant',
#    'Coloris': 'Bleu',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior performance'},
#   'available': 'Disponible',
#   'reference': '18548_b77',
#   'qualities': ['Qualité C', '120 cm', 'Qualité C', '120 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/18548-ski-occasion-junior-salomon-s-race-jr-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4/5',
#   'nb_ratings': 4,
#   'reviews': ['Dommage que les défauts ne soient pas mieux décris ou en photo',
#    'Livraison rapide et sans souci par contre déçu par les skis. Pour une qualité A ils sont pas top!',
#    'Conforme',
#    'Bien'],
#   'image_urls': 'https://freeglisse.com/69792-small_default/ski-occasion-junior-salomon-s-race-jr-fixations.jpg',
#   'pretax_price': '32.5',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '2',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '2'},
#  {'title': 'Ski occasion Volkl RTM 7.4 + fixations',
#   'brand': 'Volkl',
#   'regular_price': None,
#   'current_price': '109,00€',
#   'details': {'Type': 'Polyvalent',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Loisir',
# ...
#   'current_price': '55,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Loisir sport',
#    'Coloris': 'Blanc',
#    'Utilisateur - Configurateur': 'un junior',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior performance'},
#   'available': 'Disponible',
#   'reference': '12493_b31',
#   'qualities': ['Qualité B', '120 cm', 'Qualité B', '120 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/12493-ski-occasion-junior-head-supershape-era-20-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4/5',
#   'nb_ratings': 2,
#   'reviews': ['Ski impeccable, semelle et cares parfaites. Fixations un peu usées au niveau des plastiques mais rapport qualité-prix excellent.',
#    'conforme au descriptif à valider sur les pistes'],
#   'image_urls': 'https://freeglisse.com/56256-small_default/ski-occasion-junior-head-supershape-era-20-fixations.jpg',
#   'pretax_price': '45.833333',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '2',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion junior Dynastar Team Course WC + fixations',
#   'brand': 'Dynastar',
#   'regular_price': None,
#   'current_price': '43,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Performant',
#    'Coloris': 'Bleu',
#    'Utilisateur - Configurateur': 'un junior',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior performance'},
#   'available': 'Disponible',
#   'reference': '12566_a16',
#   'qualities': ['Qualité C', '165 cm', 'Qualité C', '165 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/12566-ski-occasion-junior-dynastar-team-course-wc-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/60639-small_default/ski-occasion-junior-dynastar-team-course-wc-fixations.jpg',
#   'pretax_price': '35.833332',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Junior ELAN RACE RC Waveflex + fixations',
#   'brand': 'Elan',
#   'regular_price': None,
#   'current_price': '59,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Loisir sport',
#    'Coloris': 'Vert',
#    'Utilisateur - Configurateur': 'un junior',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior performance'},
#   'available': 'Disponible',
#   'reference': '14184_c40',
#   'qualities': ['Qualité A', '120 cm', 'Qualité A', '120 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/14184-ski-occasion-junior-elan-race-rc-waveflex-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '5/5',
#   'nb_ratings': 2,
#   'reviews': ['Pas nouveau mais bonne condition.',
#    'pas encore essayé - aspect visuel bon'],
#   'image_urls': 'https://freeglisse.com/37280-small_default/ski-occasion-junior-elan-race-rc-waveflex-fixations.jpg',
#   'pretax_price': '49.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '2'},
#  {'title': 'Ski occasion junior Rossignol Hero Junior Pro Multi Event + fixations',
#   'brand': 'Rossignol',
#   'regular_price': None,
#   'current_price': '89,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Performant',
#    'Coloris': 'Rouge',
#    'Utilisateur - Configurateur': 'un junior',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior performance'},
#   'available': 'Disponible',
#   'reference': '14324_a30',
#   'qualities': ['Qualité A', '110 cm', 'Qualité A', '110 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/14324-ski-occasion-junior-rossignol-hero-junior-pro-multi-event-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '5/5',
#   'nb_ratings': 1,
#   'reviews': ['conforme description'],
#   'image_urls': 'https://freeglisse.com/37816-small_default/ski-occasion-junior-rossignol-hero-junior-pro-multi-event-fixations.jpg',
#   'pretax_price': '74.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '1'},
#  {'title': 'Ski occasion junior Dynastar Team Course WC + fixations',
#   'brand': 'Dynastar',
#   'regular_price': None,
#   'current_price': '45,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Compétition',
#    'Coloris': 'Bleu',
#    'Utilisateur - Configurateur': 'un junior',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior performance'},
#   'available': 'Disponible',
#   'reference': '14557_b36',
#   'qualities': ['Qualité C', '158 cm', 'Qualité C', '158 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/14557-ski-occasion-junior-dynastar-team-course-wc-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '1.5/5',
#   'nb_ratings': 2,
#   'reviews': ['Correctement classé C car le Matériel est en bon état mais a beaucoup de rayures',
#    'Les fixations bougent et ne semble pas pouvoir se resserrer. Les ski ne seront pas utilisables je pense.'],
#   'image_urls': 'https://freeglisse.com/50619-small_default/ski-occasion-junior-dynastar-team-course-wc-fixations.jpg',
#   'pretax_price': '37.5',
#   'reviews_count_1_star': '1',
#   'reviews_count_2_stars': '1',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion junior Head Team Supershape Era 2.0 + fixations',
#   'brand': 'Head',
#   'regular_price': None,
#   'current_price': '45,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Loisir sport',
#    'Coloris': 'Blanc',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior performance'},
#   'available': 'Disponible',
#   'reference': '16441_b48',
#   'qualities': ['Qualité C', '117 cm', 'Qualité C', '117 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/16441-ski-occasion-junior-head-team-supershape-era-20-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/69582-small_default/ski-occasion-junior-head-team-supershape-era-20-fixations.jpg',
#   'pretax_price': '37.5',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion junior Blizzard Racing GS + fixations',
#   'brand': 'Blizzard',
#   'regular_price': None,
#   'current_price': '29,00€',
#   'details': {'Type': 'Racing',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Compétition',
#    'Coloris': 'Orange',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior performance'},
#   'available': 'Disponible',
#   'reference': '18213_c17',
#   'qualities': ['Qualité C', '130 cm', 'Qualité C', '130 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/18213-ski-occasion-junior-blizzard-racing-gs-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/64337-small_default/ski-occasion-junior-blizzard-racing-gs-fixations.jpg',
#   'pretax_price': '24.166666',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion junior Fischer RC4 worldcup GS + fixations',
#   'brand': 'Fischer',
#   'regular_price': None,
#   'current_price': '55,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Performant',
#    'Coloris': 'Jaune',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior performance'},
#   'available': 'Disponible',
#   'reference': '18266_c33',
#   'qualities': ['Qualité B', '130 cm', 'Qualité B', '130 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/18266-ski-occasion-junior-fischer-rc4-worldcup-gs-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/67533-small_default/ski-occasion-junior-fischer-rc4-worldcup-gs-fixations.jpg',
#   'pretax_price': '45.833333',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion junior Volkl Racetiger GS + fixations',
#   'brand': 'Volkl',
#   'regular_price': None,
#   'current_price': '29,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Performant',
#    'Coloris': 'Rouge',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior performance'},
#   'available': 'Disponible',
#   'reference': '18309_c38',
#   'qualities': ['Qualité C', '150 cm', 'Qualité C', '150 cm'],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-performance/18309-ski-occasion-junior-volkl-racetiger-gs-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/67714-small_default/ski-occasion-junior-volkl-racetiger-gs-fixations.jpg',
#   'pretax_price': '24.166666',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion RANDO PACK Dynastar Cham Alti 85 + fixation Look HM 12',
#   'brand': 'Dynastar',
#   'regular_price': None,
#   'current_price': '469,00€',
#   'details': {'Type': 'Ski de randonnée',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Performant',
#    'Coloris': 'Bleu',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski de rando occasion et fin de série'},
#   'available': 'Disponible',
#   'reference': '18871_k06',
#   'qualities': ['Qualité B', '178 cm', 'Qualité B', '178 cm'],
#   'link': 'https://freeglisse.com/fr/ski-de-rando-occasion-et-fin-de-serie/18871-ski-occasion-rando-pack-dynastar-cham-alti-85-fixation-look-hm-12.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/71468-small_default/ski-occasion-rando-pack-dynastar-cham-alti-85-fixation-look-hm-12.jpg',
#   'pretax_price': '390.833333',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski de fond occasion junior Salomon Skin Race + fixation SNS Access',
#   'brand': 'Salomon',
#   'regular_price': None,
#   'current_price': '59,00€',
#   'details': {'Type': 'Alternatif',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Loisir sport',
#    'Coloris': 'Bleu',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski de fond occasion alternatif norme SNS'},
#   'available': 'Disponible',
#   'reference': '17488_mz_l13_bleu',
#   'qualities': ['Qualité A', '135 cm', 'Qualité A', '135 cm'],
#   'link': 'https://freeglisse.com/fr/ski-de-fond-occasion-alternatif-norme-sns/17488-ski-de-fond-occasion-junior-salomon-skin-race-fixation-sns-access.html',
#   'weight': '4.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': None,
#   'pretax_price': '49.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Lacroix LX Gravity + fixations',
#   'brand': 'Lacroix',
#   'regular_price': None,
#   'current_price': '329,00€',
#   'details': {'Type': 'All mountain',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Performant',
#    'Coloris': 'Gris',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion adulte performance'},
#   'available': 'Rupture de stock',
#   'reference': '16862_o11',
#   'qualities': [],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-all-mountain/16862-ski-occasion-lacroix-lx-gravity-fixations.html',
#   'weight': '6.000000',
#   'general_rate': None,
#   'nb_ratings': None,
#   'reviews': [],
#   'image_urls': 'https://freeglisse.com/49174-small_default/ski-occasion-lacroix-lx-gravity-fixations.jpg',
#   'pretax_price': '274.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion Rossignol React 8 + fixations',
#   'brand': 'Rossignol',
#   'regular_price': None,
#   'current_price': '209,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Mixte',
#    'Niveau': 'Performant',
#    'Coloris': 'Noir',
#    'Utilisateur - Configurateur': 'Adulte Performance',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion adulte performance'},
#   'available': 'Rupture de stock',
#   'reference': '16493_e18',
#   'qualities': [],
#   'link': 'https://freeglisse.com/fr/ski-occasion-adulte-performance/16493-ski-occasion-rossignol-react-8-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4/5',
#   'nb_ratings': 1,
#   'reviews': ['Correct'],
#   'image_urls': 'https://freeglisse.com/65942-small_default/ski-occasion-rossignol-react-8-fixations.jpg',
#   'pretax_price': '174.166667',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '1',
#   'reviews_count_5_stars': '0'},
#  {'title': 'Ski occasion junior Rossignol radical J + fixations',
#   'brand': 'Rossignol',
#   'regular_price': None,
#   'current_price': '39,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Junior',
#    'Niveau': 'Loisir sport',
#    'Coloris': 'Blanc',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior loisir'},
#   'available': 'Rupture de stock',
#   'reference': '11458_c56',
#   'qualities': [],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/11458-ski-occasion-junior-rossignol-radical-j-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '4.3/5',
#   'nb_ratings': 4,
#   'reviews': ['Ensemble raisonnable',
#    'Ski en très bon état, juste des rayures sur fixations en grade A',
#    'Semelle et carres en bon état.\r\nFixations desserrées... car filetage détruit dans le ski...',
#    'Los esquís llegaron encerados y su estado es el normal despues del uso que han tenido'],
#   'image_urls': 'https://freeglisse.com/43923-small_default/ski-occasion-junior-rossignol-radical-j-fixations.jpg',
#   'pretax_price': '32.5',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '1',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '3'},
#  {'title': 'Ski occasion junior K2 Rosace + fixations',
#   'brand': 'K2',
#   'regular_price': None,
#   'current_price': '39,00€',
#   'details': {'Type': 'Piste',
#    'Utilisateur': 'Fille',
#    'Niveau': 'Loisir',
#    'Coloris': 'Blanc',
#    'Economie de CO2 pour la planète (en kg)': '3.6',
#    'Type de produit': 'Ski occasion junior loisir'},
#   'available': 'Rupture de stock',
#   'reference': '14128_c06_rosace',
#   'qualities': [],
#   'link': 'https://freeglisse.com/fr/ski-occasion-junior-loisir/14128-ski-occasion-junior-k2-rosace-fixations.html',
#   'weight': '6.000000',
#   'general_rate': '5/5',
#   'nb_ratings': 1,
#   'reviews': ['Très bien.'],
#   'image_urls': 'https://freeglisse.com/37060-small_default/ski-occasion-junior-k2-rosace-fixations.jpg',
#   'pretax_price': '32.5',
#   'reviews_count_1_star': '0',
#   'reviews_count_2_stars': '0',
#   'reviews_count_3_stars': '0',
#   'reviews_count_4_stars': '0',
#   'reviews_count_5_stars': '1'}]

# %% [markdown]
# ### Convert result into a Dataframe

# %%
df = pd.DataFrame(all_product_details)
df.head()
# Out:
#                                                title           brand  \
# 0  Ski occasion Rossignol Sender 104 Ti 2023  + F...       Rossignol
# 1  Ski occasion Rossignol Sender 94 Ti 2023  + Fi...       Rossignol
# 2  Ski de fond occasion Rossignol LTS Junior + fi...       Rossignol
# 3  Ski de fond occasion Toutes marques + fixation...  Toutes marques
# 4          Ski occasion Rossignol Nova 6 + fixations       Rossignol
#
#   regular_price current_price  \
# 0    [419,00 €]       335,20€
# 1    [359,00 €]       287,20€
# 2          None        19,00€
# 3          None        15,00€
# 4          None       169,00€
#
#                                              details   available  \
# 0  {'Type': 'Freeride', 'Utilisateur': 'Mixte', '...  Disponible
# 1  {'Type': 'Freeride', 'Utilisateur': 'Mixte', '...  Disponible
# 2  {'Type': 'Alternatif', 'Utilisateur': 'Junior'...  Disponible
# 3  {'Type': 'Alternatif', 'Utilisateur': 'Mixte',...  Disponible
# 4  {'Type': 'Piste', 'Utilisateur': 'Femme', 'Niv...  Disponible
#
#              reference                                          qualities  \
# 0            18916_m27  [Qualité A, 164 cm, 172 cm, 178 cm, 186 cm, Qu...
# 1            18915_i26  [Qualité A, 156 cm, 164 cm, 172 cm, Qualité A,...
# 2  18974_mz_l18_violet  [Qualité C, 150 cm, 160 cm, 170 cm, Qualité C,...
# 3         15468_mz_l20  [Qualité C, 140 cm, 150 cm, 160 cm, 170 cm, Qu...
# 4            18890_l36  [Qualité A, Qualité B, Qualité C, 149 cm, Qual...
#
#                                                 link    weight general_rate  \
# 0  https://freeglisse.com/fr/ski-occasion-adulte-...  6.000000          5/5
# 1  https://freeglisse.com/fr/ski-occasion-adulte-...  6.000000          4/5
# 2  https://freeglisse.com/fr/ski-de-fond-occasion...  4.000000         None
# 3  https://freeglisse.com/fr/ski-de-fond-occasion...  4.000000        4.8/5
# 4  https://freeglisse.com/fr/ski-occasion-femme-l...  6.000000        3.2/5
#
#    nb_ratings                                            reviews  \
# 0         1.0  [Hormis le problème de fixations après avoir p...
# 1         1.0                                     [good cuality]
# 2         NaN                                                 []
# 3        10.0  [Je n'ai pas encore pu les tester car pas de c...
# 4         5.0  [Etat du produit conforme à mes attentes!, Gew...
#
#                                           image_urls pretax_price  \
# 0  https://freeglisse.com/70892-small_default/ski...   279.333334
# 1  https://freeglisse.com/70897-small_default/ski...   239.333334
# 2                                               None    15.833333
# 3  https://freeglisse.com/43792-small_default/ski...         12.5
# 4  https://freeglisse.com/70606-small_default/ski...   140.833333
#
#   reviews_count_1_star reviews_count_2_stars reviews_count_3_stars  \
# 0                    0                     0                     0
# 1                    0                     0                     0
# 2                    0                     0                     0
# 3                    0                     0                     0
# 4                    2                     0                     0
#
#   reviews_count_4_stars reviews_count_5_stars
# 0                     0                     1
# 1                     1                     0
# 2                     0                     0
# 3                     2                     8
# 4                     1                     2

# %% [markdown]
# ## Data cleaning and preparation

# %%
# Normalize JSON data into a flat table
details = pd.json_normalize(df['details'])

# %%
df = df[['link', 'reference', 'brand', 'title', 'regular_price','current_price', 'available', 'qualities', 'weight', 'general_rate', 'nb_ratings', 'reviews', 'image_urls', 'pretax_price', 'reviews_count_1_star', 'reviews_count_2_stars', 'reviews_count_3_stars', 'reviews_count_4_stars', 'reviews_count_5_stars']]

# %%
# Concat details to main dataframe
df = pd.concat([df, details], axis=1)

# %%
df = df.rename(columns={'current_price': 'price'})

# %%
def extract_qualities_and_sizes(qualities_list):
    quality_pattern = re.compile(r'Qualité [A-Z]')
    size_pattern = re.compile(r'\d+ cm')

    available_qualities = [q for q in qualities_list if quality_pattern.match(q)]
    sizes = [s for s in qualities_list if size_pattern.match(s)]

    # Elimination of duplicates for qualities
    available_qualities = list(set(available_qualities))
    sizes = list(set(sizes))
    
    return available_qualities, sizes

# Applying the function to each row of the dataframe
df['available_qualities'], df['sizes'] = zip(*df['qualities'].apply(extract_qualities_and_sizes))

# Display for verification
df['available_qualities'].head(), df['sizes'].head()
# Out:
# (0                          [Qualité A]
#  1                          [Qualité A]
#  2                          [Qualité C]
#  3                          [Qualité C]
#  4    [Qualité C, Qualité B, Qualité A]
#  Name: available_qualities, dtype: object,
#  0    [164 cm, 172 cm, 186 cm, 178 cm]
#  1            [164 cm, 172 cm, 156 cm]
#  2            [160 cm, 170 cm, 150 cm]
#  3    [160 cm, 140 cm, 170 cm, 150 cm]
#  4                            [149 cm]
#  Name: sizes, dtype: object)

# %%
df = df.drop(columns='qualities')
df.head()
# Out:
#                                                 link            reference  \
# 0  https://freeglisse.com/fr/ski-occasion-adulte-...            18916_m27
# 1  https://freeglisse.com/fr/ski-occasion-adulte-...            18915_i26
# 2  https://freeglisse.com/fr/ski-de-fond-occasion...  18974_mz_l18_violet
# 3  https://freeglisse.com/fr/ski-de-fond-occasion...         15468_mz_l20
# 4  https://freeglisse.com/fr/ski-occasion-femme-l...            18890_l36
#
#             brand                                              title  \
# 0       Rossignol  Ski occasion Rossignol Sender 104 Ti 2023  + F...
# 1       Rossignol  Ski occasion Rossignol Sender 94 Ti 2023  + Fi...
# 2       Rossignol  Ski de fond occasion Rossignol LTS Junior + fi...
# 3  Toutes marques  Ski de fond occasion Toutes marques + fixation...
# 4       Rossignol          Ski occasion Rossignol Nova 6 + fixations
#
#   regular_price    price   available    weight general_rate  nb_ratings  ...  \
# 0    [419,00 €]  335,20€  Disponible  6.000000          5/5         1.0  ...
# 1    [359,00 €]  287,20€  Disponible  6.000000          4/5         1.0  ...
# 2          None   19,00€  Disponible  4.000000         None         NaN  ...
# 3          None   15,00€  Disponible  4.000000        4.8/5        10.0  ...
# 4          None  169,00€  Disponible  6.000000        3.2/5         5.0  ...
#
#   reviews_count_5_stars        Type Utilisateur      Niveau Coloris  \
# 0                     1    Freeride       Mixte  Performant    Gris
# 1                     0    Freeride       Mixte  Performant    Noir
# 2                     0  Alternatif      Junior      Loisir  Violet
# 3                     8  Alternatif       Mixte      Loisir   Blanc
# 4                     2       Piste       Femme      Loisir  Violet
#
#   Utilisateur - Configurateur Economie de CO2 pour la planète (en kg)  \
# 0           Freerideur adulte                                     3.6
# 1           Freerideur adulte                                     3.6
# 2                         NaN                                     3.6
# 3                         NaN                                     3.6
# 4                   une femme                                     3.6
#
#                              Type de produit  \
# 0                      Ski occasion freeride
# 1                      Ski occasion freeride
# 2  Ski de fond occasion alternatif norme SNS
# 3  Ski de fond occasion alternatif norme SNS
# 4                  Ski occasion femme loisir
#
#                  available_qualities                             sizes
# 0                        [Qualité A]  [164 cm, 172 cm, 186 cm, 178 cm]
# 1                        [Qualité A]          [164 cm, 172 cm, 156 cm]
# 2                        [Qualité C]          [160 cm, 170 cm, 150 cm]
# 3                        [Qualité C]  [160 cm, 140 cm, 170 cm, 150 cm]
# 4  [Qualité C, Qualité B, Qualité A]                          [149 cm]
#
# [5 rows x 27 columns]

# %%
df['price'] = df['price'].str.replace(',', '.').str.replace('€', '').astype(float)

# %%
df['regular_price'] = df['regular_price'].astype(str)

# %%
df['regular_price'] = (
    df['regular_price']
    .str.extract(r'(\d+[\.,]?\d*)')[0]  # Extract numbers with a period or comma as decimal separator.
    .str.replace(',', '.')  # Replace the comma with a decimal point.
    .astype(float)  # Convert to float.
)

# %%
df['regular_price'] = df['regular_price'].replace(5, np.nan)

# %%
df['weight'] = pd.to_numeric(df['weight'], errors='coerce')
df['weight'] = df['weight'].round()

# %%
df = df.rename(columns={'Type': 'type', 
                        'Utilisateur': 'user', 
                        'Niveau': 'level', 
                        'Utilisateur - Configurateur': 'user_config', 
                        'Economie de CO2 pour la planète (en kg)': 'eco_co2',
                        'Type de produit': 'product_type',
                        'available_qualities': 'qualities',
                        'Coloris': 'color'
                        })

# %%
df['reference'] = df['reference'].str.slice(0, 5)

# %%
df.columns
# Out:
# Index(['link', 'reference', 'brand', 'title', 'regular_price', 'price',
#        'available', 'weight', 'general_rate', 'nb_ratings', 'reviews',
#        'image_urls', 'pretax_price', 'reviews_count_1_star',
#        'reviews_count_2_stars', 'reviews_count_3_stars',
#        'reviews_count_4_stars', 'reviews_count_5_stars', 'type', 'user',
#        'level', 'color', 'user_config', 'eco_co2', 'product_type', 'qualities',
#        'sizes'],
#       dtype='object')

# %%
columns_order = ['link', 'reference', 'brand', 'title', 'available', 'pretax_price', 'regular_price', 'price', 'type', 'user', 'level', 'color',
        'user_config', 'eco_co2', 'product_type', 'qualities', 'sizes', 'weight', 'general_rate', 'nb_ratings', 'reviews',
        'reviews_count_1_star', 'reviews_count_2_stars', 'reviews_count_3_stars', 'reviews_count_4_stars', 'reviews_count_5_stars', 'image_urls']
df = df[columns_order]

# %%
df['pretax_price'] = round(df['pretax_price'].astype(float), 2)

# %%
df['reviews_count_1_star'] = df['reviews_count_1_star'].astype(int)
df['reviews_count_2_stars'] = df['reviews_count_2_stars'].astype(int)
df['reviews_count_3_stars'] = df['reviews_count_3_stars'].astype(int)
df['reviews_count_4_stars'] = df['reviews_count_4_stars'].astype(int)
df['reviews_count_5_stars'] = df['reviews_count_5_stars'].astype(int)

# %% [markdown]
# ### Creation of a new dataframe dedicated to ratings

# %%
columns_ratings = ['link', 'general_rate', 'nb_ratings', 'reviews_count_1_star', 'reviews_count_2_stars', 'reviews_count_3_stars',
                    'reviews_count_4_stars', 'reviews_count_5_stars', 'reviews']
df_ratings = df[columns_ratings]
df_ratings.head()
# Out:
#                                                 link general_rate  nb_ratings  \
# 0  https://freeglisse.com/fr/ski-occasion-adulte-...          5/5         1.0
# 1  https://freeglisse.com/fr/ski-occasion-adulte-...          4/5         1.0
# 2  https://freeglisse.com/fr/ski-de-fond-occasion...         None         NaN
# 3  https://freeglisse.com/fr/ski-de-fond-occasion...        4.8/5        10.0
# 4  https://freeglisse.com/fr/ski-occasion-femme-l...        3.2/5         5.0
#
#    reviews_count_1_star  reviews_count_2_stars  reviews_count_3_stars  \
# 0                     0                      0                      0
# 1                     0                      0                      0
# 2                     0                      0                      0
# 3                     0                      0                      0
# 4                     2                      0                      0
#
#    reviews_count_4_stars  reviews_count_5_stars  \
# 0                      0                      1
# 1                      1                      0
# 2                      0                      0
# 3                      2                      8
# 4                      1                      2
#
#                                              reviews
# 0  [Hormis le problème de fixations après avoir p...
# 1                                     [good cuality]
# 2                                                 []
# 3  [Je n'ai pas encore pu les tester car pas de c...
# 4  [Etat du produit conforme à mes attentes!, Gew...

# %% [markdown]
# ### Export ratings dataframe

# %%
df_ratings.to_csv('ratings.csv')

# %% [markdown]
# ### Creation of a new dataframe dedicated to products details

# %%
columns_product = ['link', 'reference', 'brand', 'title', 'available', 'type', 'product_type', 'user', 
                    'level', 'user_config', 'color', 'sizes', 'weight',
                    'image_urls', 'price', 'regular_price', 'pretax_price', 'eco_co2']
df_product = df[columns_product]
df_product.head()
# Out:
#                                                 link reference  \
# 0  https://freeglisse.com/fr/ski-occasion-adulte-...     18916
# 1  https://freeglisse.com/fr/ski-occasion-adulte-...     18915
# 2  https://freeglisse.com/fr/ski-de-fond-occasion...     18974
# 3  https://freeglisse.com/fr/ski-de-fond-occasion...     15468
# 4  https://freeglisse.com/fr/ski-occasion-femme-l...     18890
#
#             brand                                              title  \
# 0       Rossignol  Ski occasion Rossignol Sender 104 Ti 2023  + F...
# 1       Rossignol  Ski occasion Rossignol Sender 94 Ti 2023  + Fi...
# 2       Rossignol  Ski de fond occasion Rossignol LTS Junior + fi...
# 3  Toutes marques  Ski de fond occasion Toutes marques + fixation...
# 4       Rossignol          Ski occasion Rossignol Nova 6 + fixations
#
#     available        type                               product_type    user  \
# 0  Disponible    Freeride                      Ski occasion freeride   Mixte
# 1  Disponible    Freeride                      Ski occasion freeride   Mixte
# 2  Disponible  Alternatif  Ski de fond occasion alternatif norme SNS  Junior
# 3  Disponible  Alternatif  Ski de fond occasion alternatif norme SNS   Mixte
# 4  Disponible       Piste                  Ski occasion femme loisir   Femme
#
#         level        user_config   color                             sizes  \
# 0  Performant  Freerideur adulte    Gris  [164 cm, 172 cm, 186 cm, 178 cm]
# 1  Performant  Freerideur adulte    Noir          [164 cm, 172 cm, 156 cm]
# 2      Loisir                NaN  Violet          [160 cm, 170 cm, 150 cm]
# 3      Loisir                NaN   Blanc  [160 cm, 140 cm, 170 cm, 150 cm]
# 4      Loisir          une femme  Violet                          [149 cm]
#
#    weight                                         image_urls  price  \
# 0     6.0  https://freeglisse.com/70892-small_default/ski...  335.2
# 1     6.0  https://freeglisse.com/70897-small_default/ski...  287.2
# 2     4.0                                               None   19.0
# 3     4.0  https://freeglisse.com/43792-small_default/ski...   15.0
# 4     6.0  https://freeglisse.com/70606-small_default/ski...  169.0
#
#    regular_price  pretax_price eco_co2
# 0          419.0        279.33     3.6
# 1          359.0        239.33     3.6
# 2            NaN         15.83     3.6
# 3            NaN         12.50     3.6
# 4            NaN        140.83     3.6

# %%
df.set_index('link')
# Out:
#                                                    reference           brand  \
# link
# https://freeglisse.com/fr/ski-occasion-adulte-f...     18916       Rossignol
# https://freeglisse.com/fr/ski-occasion-adulte-f...     18915       Rossignol
# https://freeglisse.com/fr/ski-de-fond-occasion-...     18974       Rossignol
# https://freeglisse.com/fr/ski-de-fond-occasion-...     15468  Toutes marques
# https://freeglisse.com/fr/ski-occasion-femme-lo...     18890       Rossignol
# ...                                                      ...             ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...     17488         Salomon
# https://freeglisse.com/fr/ski-occasion-adulte-a...     16862         Lacroix
# https://freeglisse.com/fr/ski-occasion-adulte-p...     16493       Rossignol
# https://freeglisse.com/fr/ski-occasion-junior-l...     11458       Rossignol
# https://freeglisse.com/fr/ski-occasion-junior-l...     14128              K2
#
#                                                                                                 title  \
# link
# https://freeglisse.com/fr/ski-occasion-adulte-f...  Ski occasion Rossignol Sender 104 Ti 2023  + F...
# https://freeglisse.com/fr/ski-occasion-adulte-f...  Ski occasion Rossignol Sender 94 Ti 2023  + Fi...
# https://freeglisse.com/fr/ski-de-fond-occasion-...  Ski de fond occasion Rossignol LTS Junior + fi...
# https://freeglisse.com/fr/ski-de-fond-occasion-...  Ski de fond occasion Toutes marques + fixation...
# https://freeglisse.com/fr/ski-occasion-femme-lo...          Ski occasion Rossignol Nova 6 + fixations
# ...                                                                                               ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...  Ski de fond occasion junior Salomon Skin Race ...
# https://freeglisse.com/fr/ski-occasion-adulte-a...        Ski occasion Lacroix LX Gravity + fixations
# https://freeglisse.com/fr/ski-occasion-adulte-p...         Ski occasion Rossignol React 8 + fixations
# https://freeglisse.com/fr/ski-occasion-junior-l...  Ski occasion junior Rossignol radical J + fixa...
# https://freeglisse.com/fr/ski-occasion-junior-l...          Ski occasion junior K2 Rosace + fixations
#
#                                                            available  \
# link
# https://freeglisse.com/fr/ski-occasion-adulte-f...        Disponible
# https://freeglisse.com/fr/ski-occasion-adulte-f...        Disponible
# https://freeglisse.com/fr/ski-de-fond-occasion-...        Disponible
# https://freeglisse.com/fr/ski-de-fond-occasion-...        Disponible
# https://freeglisse.com/fr/ski-occasion-femme-lo...        Disponible
# ...                                                              ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...        Disponible
# https://freeglisse.com/fr/ski-occasion-adulte-a...  Rupture de stock
# https://freeglisse.com/fr/ski-occasion-adulte-p...  Rupture de stock
# https://freeglisse.com/fr/ski-occasion-junior-l...  Rupture de stock
# https://freeglisse.com/fr/ski-occasion-junior-l...  Rupture de stock
#
#                                                     pretax_price  \
# link
# https://freeglisse.com/fr/ski-occasion-adulte-f...        279.33
# https://freeglisse.com/fr/ski-occasion-adulte-f...        239.33
# https://freeglisse.com/fr/ski-de-fond-occasion-...         15.83
# https://freeglisse.com/fr/ski-de-fond-occasion-...         12.50
# https://freeglisse.com/fr/ski-occasion-femme-lo...        140.83
# ...                                                          ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...         49.17
# https://freeglisse.com/fr/ski-occasion-adulte-a...        274.17
# https://freeglisse.com/fr/ski-occasion-adulte-p...        174.17
# https://freeglisse.com/fr/ski-occasion-junior-l...         32.50
# https://freeglisse.com/fr/ski-occasion-junior-l...         32.50
#
#                                                     regular_price  price  \
# link
# https://freeglisse.com/fr/ski-occasion-adulte-f...          419.0  335.2
# https://freeglisse.com/fr/ski-occasion-adulte-f...          359.0  287.2
# https://freeglisse.com/fr/ski-de-fond-occasion-...            NaN   19.0
# https://freeglisse.com/fr/ski-de-fond-occasion-...            NaN   15.0
# https://freeglisse.com/fr/ski-occasion-femme-lo...            NaN  169.0
# ...                                                           ...    ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...            NaN   59.0
# https://freeglisse.com/fr/ski-occasion-adulte-a...            NaN  329.0
# https://freeglisse.com/fr/ski-occasion-adulte-p...            NaN  209.0
# https://freeglisse.com/fr/ski-occasion-junior-l...            NaN   39.0
# https://freeglisse.com/fr/ski-occasion-junior-l...            NaN   39.0
#
#                                                             type    user  \
# link
# https://freeglisse.com/fr/ski-occasion-adulte-f...      Freeride   Mixte
# https://freeglisse.com/fr/ski-occasion-adulte-f...      Freeride   Mixte
# https://freeglisse.com/fr/ski-de-fond-occasion-...    Alternatif  Junior
# https://freeglisse.com/fr/ski-de-fond-occasion-...    Alternatif   Mixte
# https://freeglisse.com/fr/ski-occasion-femme-lo...         Piste   Femme
# ...                                                          ...     ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...    Alternatif  Junior
# https://freeglisse.com/fr/ski-occasion-adulte-a...  All mountain   Mixte
# https://freeglisse.com/fr/ski-occasion-adulte-p...         Piste   Mixte
# https://freeglisse.com/fr/ski-occasion-junior-l...         Piste  Junior
# https://freeglisse.com/fr/ski-occasion-junior-l...         Piste   Fille
#
#                                                            level  ... weight  \
# link                                                              ...
# https://freeglisse.com/fr/ski-occasion-adulte-f...    Performant  ...    6.0
# https://freeglisse.com/fr/ski-occasion-adulte-f...    Performant  ...    6.0
# https://freeglisse.com/fr/ski-de-fond-occasion-...        Loisir  ...    4.0
# https://freeglisse.com/fr/ski-de-fond-occasion-...        Loisir  ...    4.0
# https://freeglisse.com/fr/ski-occasion-femme-lo...        Loisir  ...    6.0
# ...                                                          ...  ...    ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...  Loisir sport  ...    4.0
# https://freeglisse.com/fr/ski-occasion-adulte-a...    Performant  ...    6.0
# https://freeglisse.com/fr/ski-occasion-adulte-p...    Performant  ...    6.0
# https://freeglisse.com/fr/ski-occasion-junior-l...  Loisir sport  ...    6.0
# https://freeglisse.com/fr/ski-occasion-junior-l...        Loisir  ...    6.0
#
#                                                    general_rate nb_ratings  \
# link
# https://freeglisse.com/fr/ski-occasion-adulte-f...          5/5        1.0
# https://freeglisse.com/fr/ski-occasion-adulte-f...          4/5        1.0
# https://freeglisse.com/fr/ski-de-fond-occasion-...         None        NaN
# https://freeglisse.com/fr/ski-de-fond-occasion-...        4.8/5       10.0
# https://freeglisse.com/fr/ski-occasion-femme-lo...        3.2/5        5.0
# ...                                                         ...        ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...         None        NaN
# https://freeglisse.com/fr/ski-occasion-adulte-a...         None        NaN
# https://freeglisse.com/fr/ski-occasion-adulte-p...          4/5        1.0
# https://freeglisse.com/fr/ski-occasion-junior-l...        4.3/5        4.0
# https://freeglisse.com/fr/ski-occasion-junior-l...          5/5        1.0
#
#                                                                                               reviews  \
# link
# https://freeglisse.com/fr/ski-occasion-adulte-f...  [Hormis le problème de fixations après avoir p...
# https://freeglisse.com/fr/ski-occasion-adulte-f...                                     [good cuality]
# https://freeglisse.com/fr/ski-de-fond-occasion-...                                                 []
# https://freeglisse.com/fr/ski-de-fond-occasion-...  [Je n'ai pas encore pu les tester car pas de c...
# https://freeglisse.com/fr/ski-occasion-femme-lo...  [Etat du produit conforme à mes attentes!, Gew...
# ...                                                                                               ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...                                                 []
# https://freeglisse.com/fr/ski-occasion-adulte-a...                                                 []
# https://freeglisse.com/fr/ski-occasion-adulte-p...                                          [Correct]
# https://freeglisse.com/fr/ski-occasion-junior-l...  [Ensemble raisonnable, Ski en très bon état, j...
# https://freeglisse.com/fr/ski-occasion-junior-l...                                       [Très bien.]
#
#                                                    reviews_count_1_star  \
# link
# https://freeglisse.com/fr/ski-occasion-adulte-f...                    0
# https://freeglisse.com/fr/ski-occasion-adulte-f...                    0
# https://freeglisse.com/fr/ski-de-fond-occasion-...                    0
# https://freeglisse.com/fr/ski-de-fond-occasion-...                    0
# https://freeglisse.com/fr/ski-occasion-femme-lo...                    2
# ...                                                                 ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...                    0
# https://freeglisse.com/fr/ski-occasion-adulte-a...                    0
# https://freeglisse.com/fr/ski-occasion-adulte-p...                    0
# https://freeglisse.com/fr/ski-occasion-junior-l...                    0
# https://freeglisse.com/fr/ski-occasion-junior-l...                    0
#
#                                                    reviews_count_2_stars  \
# link
# https://freeglisse.com/fr/ski-occasion-adulte-f...                     0
# https://freeglisse.com/fr/ski-occasion-adulte-f...                     0
# https://freeglisse.com/fr/ski-de-fond-occasion-...                     0
# https://freeglisse.com/fr/ski-de-fond-occasion-...                     0
# https://freeglisse.com/fr/ski-occasion-femme-lo...                     0
# ...                                                                  ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...                     0
# https://freeglisse.com/fr/ski-occasion-adulte-a...                     0
# https://freeglisse.com/fr/ski-occasion-adulte-p...                     0
# https://freeglisse.com/fr/ski-occasion-junior-l...                     1
# https://freeglisse.com/fr/ski-occasion-junior-l...                     0
#
#                                                     reviews_count_3_stars  \
# link
# https://freeglisse.com/fr/ski-occasion-adulte-f...                      0
# https://freeglisse.com/fr/ski-occasion-adulte-f...                      0
# https://freeglisse.com/fr/ski-de-fond-occasion-...                      0
# https://freeglisse.com/fr/ski-de-fond-occasion-...                      0
# https://freeglisse.com/fr/ski-occasion-femme-lo...                      0
# ...                                                                   ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...                      0
# https://freeglisse.com/fr/ski-occasion-adulte-a...                      0
# https://freeglisse.com/fr/ski-occasion-adulte-p...                      0
# https://freeglisse.com/fr/ski-occasion-junior-l...                      0
# https://freeglisse.com/fr/ski-occasion-junior-l...                      0
#
#                                                    reviews_count_4_stars  \
# link
# https://freeglisse.com/fr/ski-occasion-adulte-f...                     0
# https://freeglisse.com/fr/ski-occasion-adulte-f...                     1
# https://freeglisse.com/fr/ski-de-fond-occasion-...                     0
# https://freeglisse.com/fr/ski-de-fond-occasion-...                     2
# https://freeglisse.com/fr/ski-occasion-femme-lo...                     1
# ...                                                                  ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...                     0
# https://freeglisse.com/fr/ski-occasion-adulte-a...                     0
# https://freeglisse.com/fr/ski-occasion-adulte-p...                     1
# https://freeglisse.com/fr/ski-occasion-junior-l...                     0
# https://freeglisse.com/fr/ski-occasion-junior-l...                     0
#
#                                                     reviews_count_5_stars  \
# link
# https://freeglisse.com/fr/ski-occasion-adulte-f...                      1
# https://freeglisse.com/fr/ski-occasion-adulte-f...                      0
# https://freeglisse.com/fr/ski-de-fond-occasion-...                      0
# https://freeglisse.com/fr/ski-de-fond-occasion-...                      8
# https://freeglisse.com/fr/ski-occasion-femme-lo...                      2
# ...                                                                   ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...                      0
# https://freeglisse.com/fr/ski-occasion-adulte-a...                      0
# https://freeglisse.com/fr/ski-occasion-adulte-p...                      0
# https://freeglisse.com/fr/ski-occasion-junior-l...                      3
# https://freeglisse.com/fr/ski-occasion-junior-l...                      1
#
#                                                                                            image_urls
# link
# https://freeglisse.com/fr/ski-occasion-adulte-f...  https://freeglisse.com/70892-small_default/ski...
# https://freeglisse.com/fr/ski-occasion-adulte-f...  https://freeglisse.com/70897-small_default/ski...
# https://freeglisse.com/fr/ski-de-fond-occasion-...                                               None
# https://freeglisse.com/fr/ski-de-fond-occasion-...  https://freeglisse.com/43792-small_default/ski...
# https://freeglisse.com/fr/ski-occasion-femme-lo...  https://freeglisse.com/70606-small_default/ski...
# ...                                                                                               ...
# https://freeglisse.com/fr/ski-de-fond-occasion-...                                               None
# https://freeglisse.com/fr/ski-occasion-adulte-a...  https://freeglisse.com/49174-small_default/ski...
# https://freeglisse.com/fr/ski-occasion-adulte-p...  https://freeglisse.com/65942-small_default/ski...
# https://freeglisse.com/fr/ski-occasion-junior-l...  https://freeglisse.com/43923-small_default/ski...
# https://freeglisse.com/fr/ski-occasion-junior-l...  https://freeglisse.com/37060-small_default/ski...
#
# [169 rows x 26 columns]

# %% [markdown]
# ### Export products dataframe

# %%
df.to_csv('products.csv')
